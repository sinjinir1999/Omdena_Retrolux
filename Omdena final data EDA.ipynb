# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\pankt\\OneDrive\\Desktop\\Projects\\Omdena\\Final_complete.csv")

# %%
data.shape
# Out:
# (5425, 49)

# %%
findata=data.drop(data.iloc[:, [0]], axis=1)
findata.shape
# Out:
# (5425, 48)

# %%
findata.columns
# Out:
# Index(['project_id', 'option_id', 'option_calculation_id', 'company_id',
#        'projects_name', 'facility_type_id', 'facility_type',
#        'industry_type_id', 'name', 'started_at', 'finished_at',
#        'tax_rate_source', 'finance_discount_rate', 'tax_exempt', 'active',
#        'area_count', 'area_count_sum', 'ave_annual_hours',
#        'monday_ave_daily_hours', 'tuesday_ave_daily_hours',
#        'wednesday_ave_daily_hours', 'thursday_ave_daily_hours',
#        'friday_ave_daily_hours', 'saturday_ave_daily_hours',
#        'sunday_ave_daily_hours', 'ave_weeks_per_year', 'hour_type',
#        'max_kwh_cost', 'max_kwh_cost_simple', 'existing_lighting_count',
#        'total_watts_per_product', 'ave_lm70', 'total_solution_count',
#        'total_existing_quantity', 'total_proposed_quantity',
#        'total_replacement_count', 'total_fixture_watts',
#        'total_fixture_watt_hours', 'total_fixture_life_years',
#        'total_item_watts', 'sol_total_existing_count', 'total_product_count',
#        'energy_savings_per_year', 'total_savings_per_year', 'rebates',
#        'net_replacement_cost', 'payback', 'ROI'],
#       dtype='object')

# %%
findata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5425 entries, 0 to 5424
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   project_id                 5425 non-null   int64
#  1   option_id                  5425 non-null   int64
#  2   option_calculation_id      5425 non-null   int64
#  3   company_id                 5425 non-null   int64
#  4   projects_name              5425 non-null   object
#  5   facility_type_id           2439 non-null   float64
#  6   facility_type              2439 non-null   object
#  7   industry_type_id           2504 non-null   float64
#  8   name                       5425 non-null   object
#  9   started_at                 5425 non-null   object
#  10  finished_at                5425 non-null   object
#  11  tax_rate_source            5410 non-null   float64
#  12  finance_discount_rate      5425 non-null   int64
#  13  tax_exempt                 5425 non-null   bool
#  14  active                     5425 non-null   bool
#  15  area_count                 5425 non-null   int64
#  16  area_count_sum             5425 non-null   int64
#  17  ave_annual_hours           4784 non-null   float64
#  18  monday_ave_daily_hours     5038 non-null   float64
#  19  tuesday_ave_daily_hours    5038 non-null   float64
#  20  wednesday_ave_daily_hours  5038 non-null   float64
#  21  thursday_ave_daily_hours   5035 non-null   float64
#  22  friday_ave_daily_hours     5035 non-null   float64
#  23  saturday_ave_daily_hours   5038 non-null   float64
#  24  sunday_ave_daily_hours     5038 non-null   float64
#  25  ave_weeks_per_year         5038 non-null   float64
#  26  hour_type                  5157 non-null   float64
#  27  max_kwh_cost               4947 non-null   float64
#  28  max_kwh_cost_simple        93 non-null     float64
#  29  existing_lighting_count    5425 non-null   int64
#  30  total_watts_per_product    5425 non-null   float64
#  31  ave_lm70                   5425 non-null   float64
#  32  total_solution_count       5425 non-null   int64
#  33  total_existing_quantity    5425 non-null   int64
#  34  total_proposed_quantity    5425 non-null   int64
#  35  total_replacement_count    5183 non-null   float64
#  36  total_fixture_watts        5183 non-null   float64
#  37  total_fixture_watt_hours   5183 non-null   float64
#  38  total_fixture_life_years   5183 non-null   float64
#  39  total_item_watts           5183 non-null   float64
#  40  sol_total_existing_count   5425 non-null   int64
#  41  total_product_count        5425 non-null   int64
#  42  energy_savings_per_year    5425 non-null   float64
#  43  total_savings_per_year     5425 non-null   float64
#  44  rebates                    1095 non-null   float64
#  45  net_replacement_cost       5425 non-null   float64
#  46  payback                    4287 non-null   float64
#  47  ROI                        5341 non-null   float64
# dtypes: bool(2), float64(28), int64(13), object(5)
# memory usage: 1.9+ MB

# %%
findata.head(10)
# Out:
#    project_id  option_id  option_calculation_id  company_id  \
# 0           3          8                   1235           5
# 1           8        290                   1398           7
# 2          11         92                   1221          15
# 3          15         21                   1782          19
# 4          15        928                   1781          19
# 5          16          7                   1262           7
# 6          22          3                   1242          25
# 7          23          5                   1245          26
# 8          24          4                   1229           7
# 9          25         10                   1230          27
#
#                                     projects_name  facility_type_id  \
# 0                               Eagle Enterprises               NaN
# 1                                  Acme Warehouse               NaN
# 2                                Golden Spoon_257              19.0
# 3  Demo Project - updated and synced name - again               NaN
# 4  Demo Project - updated and synced name - again               NaN
# 5                              Acme Grocery Store               2.0
# 6                                          Test 1               1.0
# 7                 Eastern-Idaho Technical College              56.0
# 8                              Acme Bank Building              16.0
# 9                              Blue Max Trucking                1.0
#
#                     facility_type  industry_type_id  \
# 0                             NaN            2252.0
# 1                             NaN               NaN
# 2           Fast Food Restaurants               NaN
# 3                             NaN            2336.0
# 4                             NaN            2336.0
# 5                          Bakery               NaN
# 6                    Auto Related            2214.0
# 7  Schools (Technical/Vocational)            2238.0
# 8                   Entertainment               NaN
# 9                    Auto Related            2254.0
#
#                              name started_at  ... total_fixture_life_years  \
# 0    Trantow, Langworth and Moore    34:45.0  ...                 0.000000
# 1             Bartoletti and Sons    28:04.8  ...                50.000000
# 2     Anderson, Shields and Hyatt    43:31.8  ...                 0.000000
# 3    Blanda, Stiedemann and Kiehn    40:38.1  ...                 0.000000
# 4    Blanda, Stiedemann and Kiehn    55:33.8  ...               180.288462
# 5             Bartoletti and Sons    28:08.6  ...                25.000000
# 6                      Renner Inc    34:38.0  ...                 0.000000
# 7                         Toy LLC    33:11.9  ...                 0.000000
# 8             Bartoletti and Sons    35:07.5  ...                93.457944
# 9  Goldner, Schaefer and Kshlerin    34:53.0  ...                 0.000000
#
#    total_item_watts  sol_total_existing_count  total_product_count  \
# 0               0.0                         4                    4
# 1             130.0                         1                    1
# 2           12900.0                         2                    2
# 3               0.0                         6                    6
# 4            1681.0                        12                   10
# 5             100.0                         1                    1
# 6               0.0                         1                    1
# 7               0.0                        30                   30
# 8            4038.0                        52                   49
# 9               0.0                         1                    1
#
#    energy_savings_per_year  total_savings_per_year  rebates  \
# 0             0.000000e+00            0.000000e+00     18.0
# 1             8.700000e+01            3.536667e+02      NaN
# 2             0.000000e+00            0.000000e+00      NaN
# 3             6.220000e-15            6.220000e-15      NaN
# 4             9.665942e+02            1.044594e+03      NaN
# 5             1.760000e+02            3.260000e+02      NaN
# 6             2.000000e+03            1.595936e+03      NaN
# 7             3.337817e+04            3.337817e+04      NaN
# 8             1.316460e+04            1.316460e+04      NaN
# 9             6.558926e+03            6.558926e+03      NaN
#
#    net_replacement_cost  payback         ROI
# 0                2.1300      NaN    0.000000
# 1              119.0000     0.34  297.198880
# 2            13330.0000      NaN    0.000000
# 3                0.0000      NaN         inf
# 4             8489.2094      NaN   12.304965
# 5              615.2000     1.89   52.990897
# 6             3740.0000      NaN   42.672092
# 7           216562.1142      NaN   15.412744
# 8             6528.9914     1.32  201.632908
# 9            13845.0000      NaN   47.373972
#
# [10 rows x 48 columns]

# %%
findata['ROI'].describe()
# Out:
# count    5341.000000
# mean             inf
# std              NaN
# min         0.000000
# 25%        17.492833
# 50%        34.205138
# 75%        61.332027
# max              inf
# Name: ROI, dtype: float64

# %%
findata['ROI'].isna().sum()
# Out:
# 84

# %%
findata['ROI'].shape
# Out:
# (5425,)

# %%
findata.describe()
# Out:
#          project_id     option_id  option_calculation_id   company_id  \
# count   5425.000000   5425.000000            5425.000000  5425.000000
# mean    6373.630599   5969.140461            5975.823779   412.121106
# std     3376.875896   2820.018901            2777.033745   207.762946
# min        3.000000      3.000000               1.000000     5.000000
# 25%     4121.000000   4069.000000            4034.000000   276.000000
# 50%     6215.000000   6272.000000            6237.000000   407.000000
# 75%     9377.000000   8331.000000            8327.000000   565.000000
# max    12143.000000  10292.000000           10288.000000  1050.000000
#
#        facility_type_id  industry_type_id  tax_rate_source  \
# count       2439.000000       2504.000000      5410.000000
# mean          36.079131       2263.609425         1.999630
# std           18.615444         39.020949         0.027191
# min            1.000000       2214.000000         0.000000
# 25%           24.000000       2239.000000         2.000000
# 50%           39.000000       2249.000000         2.000000
# 75%           52.000000       2254.000000         2.000000
# max           65.000000       2357.000000         2.000000
#
#        finance_discount_rate   area_count  area_count_sum  ...  \
# count                 5425.0  5425.000000    5.425000e+03  ...
# mean                     5.0     6.025622    1.226107e+04  ...
# std                      0.0     6.464668    1.556819e+05  ...
# min                      5.0     1.000000    1.000000e+00  ...
# 25%                      5.0     2.000000    8.000000e+00  ...
# 50%                      5.0     4.000000    6.300000e+01  ...
# 75%                      5.0     8.000000    4.640000e+02  ...
# max                      5.0    90.000000    7.680576e+06  ...
#
#        total_fixture_life_years  total_item_watts  sol_total_existing_count  \
# count              5.183000e+03      5.183000e+03               5425.000000
# mean               3.004153e+03      8.679085e+04                 46.892166
# std                6.386603e+04      4.626062e+06                216.811908
# min                0.000000e+00      0.000000e+00                  1.000000
# 25%                3.250252e+01      2.177500e+03                  3.000000
# 50%                1.052632e+02      6.395600e+03                  8.000000
# 75%                3.604499e+02      1.868150e+04                 27.000000
# max                2.118326e+06      3.329675e+08               7909.000000
#
#        total_product_count  energy_savings_per_year  total_savings_per_year  \
# count          5425.000000             5.425000e+03            5.425000e+03
# mean             54.222673             8.476328e+06            8.495115e+06
# std             226.133532             6.232114e+08            6.232122e+08
# min               0.000000            -4.640000e+03            0.000000e+00
# 25%               3.000000             8.414515e+02            9.593129e+02
# 50%              10.000000             3.621822e+03            4.194590e+03
# 75%              33.000000             1.154672e+04            1.300414e+04
# max            7059.000000             4.590240e+10            4.590240e+10
#
#             rebates  net_replacement_cost      payback          ROI
# count  1.095000e+03          5.425000e+03  4287.000000  5341.000000
# mean   1.320295e+04          4.244899e+06     2.837940          inf
# std    7.341061e+04          3.094538e+08     1.915617          NaN
# min   -4.300000e+03          0.000000e+00     0.000000     0.000000
# 25%    1.200000e+03          3.758090e+03     1.450000    17.492833
# 50%    3.563200e+03          1.279451e+04     2.460000    34.205138
# 75%    1.133363e+04          3.594089e+04     3.840000    61.332027
# max    1.681374e+06          2.279273e+10     9.990000          inf
#
# [8 rows x 41 columns]

# %%
x = findata.describe()

# %%
descd = findata.describe()

for i in range(41):
    print(descd.iloc[:,[i]])
    print("\n")
# Out:
#          project_id
# count   5425.000000
# mean    6373.630599
# std     3376.875896
# min        3.000000
# 25%     4121.000000
# 50%     6215.000000
# 75%     9377.000000
# max    12143.000000
#
#
#           option_id
# count   5425.000000
# mean    5969.140461
# std     2820.018901
# min        3.000000
# 25%     4069.000000
# 50%     6272.000000
# 75%     8331.000000
# max    10292.000000
#
#
#        option_calculation_id
# count            5425.000000
# mean             5975.823779
# std              2777.033745
# min                 1.000000
# 25%              4034.000000
# 50%              6237.000000
# 75%              8327.000000
# max             10288.000000
#
#
#         company_id
# count  5425.000000
# mean    412.121106
# std     207.762946
# min       5.000000
# 25%     276.000000
# 50%     407.000000
# 75%     565.000000
# max    1050.000000
#
#
#        facility_type_id
# count       2439.000000
# mean          36.079131
# std           18.615444
# min            1.000000
# 25%           24.000000
# 50%           39.000000
# 75%           52.000000
# max           65.000000
#
#
#        industry_type_id
# count       2504.000000
# mean        2263.609425
# std           39.020949
# min         2214.000000
# 25%         2239.000000
# 50%         2249.000000
# 75%         2254.000000
# max         2357.000000
#
#
#        tax_rate_source
# count      5410.000000
# mean          1.999630
# std           0.027191
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           2.000000
# max           2.000000
#
#
#        finance_discount_rate
# count                 5425.0
# mean                     5.0
# std                      0.0
# min                      5.0
# 25%                      5.0
# 50%                      5.0
# 75%                      5.0
# max                      5.0
#
#
#         area_count
# count  5425.000000
# mean      6.025622
# std       6.464668
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       8.000000
# max      90.000000
#
#
#        area_count_sum
# count    5.425000e+03
# mean     1.226107e+04
# std      1.556819e+05
# min      1.000000e+00
# 25%      8.000000e+00
# 50%      6.300000e+01
# 75%      4.640000e+02
# max      7.680576e+06
#
#
#        ave_annual_hours
# count       4784.000000
# mean        4249.181784
# std         1701.241853
# min            0.000000
# 25%         3120.000000
# 50%         4060.000000
# 75%         4802.833333
# max        28105.000000
#
#
#        monday_ave_daily_hours
# count             5038.000000
# mean                 1.416117
# std                  3.958970
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                 24.000000
#
#
#        tuesday_ave_daily_hours
# count              5038.000000
# mean                  1.418917
# std                   3.958635
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max                  24.000000
#
#
#        wednesday_ave_daily_hours
# count                5038.000000
# mean                    1.427601
# std                     3.969743
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                    24.000000
#
#
#        thursday_ave_daily_hours
# count               5035.000000
# mean                   1.421139
# std                    3.962024
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                   24.000000
#
#
#        friday_ave_daily_hours
# count             5035.000000
# mean                 1.421274
# std                  3.966296
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                 24.000000
#
#
#        saturday_ave_daily_hours
# count               5038.000000
# mean                   0.911292
# std                    3.139215
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                   24.000000
#
#
#        sunday_ave_daily_hours
# count             5038.000000
# mean                 0.520670
# std                  2.523115
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                 24.000000
#
#
#        ave_weeks_per_year
# count         5038.000000
# mean             6.101727
# std             15.933965
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max            120.000000
#
#
#          hour_type
# count  5157.000000
# mean      1.130502
# std       0.336888
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
#
#
#        max_kwh_cost
# count   4947.000000
# mean       6.554901
# std      206.965160
# min        0.000000
# 25%        0.087900
# 50%        0.100000
# 75%        0.124200
# max     8760.000000
#
#
#        max_kwh_cost_simple
# count            93.000000
# mean              0.155228
# std               0.242960
# min               0.000000
# 25%               0.063000
# 50%               0.085000
# 75%               0.100000
# max               0.961000
#
#
#        existing_lighting_count
# count              5425.000000
# mean                  6.025622
# std                   6.464668
# min                   1.000000
# 25%                   2.000000
# 50%                   4.000000
# 75%                   8.000000
# max                  90.000000
#
#
#        total_watts_per_product
# count             5.425000e+03
# mean              7.736680e+07
# std               1.270550e+09
# min               0.000000e+00
# 25%               2.880000e+03
# 50%               3.162600e+04
# 75%               3.527030e+05
# max               6.705777e+10
#
#
#             ave_lm70
# count    5425.000000
# mean    16626.401596
# std      7138.407137
# min         0.000000
# 25%     12388.888890
# 50%     16437.500000
# 75%     20000.000000
# max    156000.000000
#
#
#        total_solution_count
# count           5425.000000
# mean               6.025622
# std                6.464668
# min                1.000000
# 25%                2.000000
# 50%                4.000000
# 75%                8.000000
# max               90.000000
#
#
#        total_existing_quantity
# count             5.425000e+03
# mean              6.441607e+03
# std               5.496588e+04
# min               0.000000e+00
# 25%               4.500000e+01
# 50%               1.950000e+02
# 75%               9.930000e+02
# max               2.375117e+06
#
#
#        total_proposed_quantity
# count             5.425000e+03
# mean              9.119975e+03
# std               1.106861e+05
# min               0.000000e+00
# 25%               4.300000e+01
# 50%               2.110000e+02
# 75%               1.198000e+03
# max               6.628561e+06
#
#
#        total_replacement_count
# count             5.183000e+03
# mean              8.287177e+02
# std               1.404307e+04
# min               0.000000e+00
# 25%               4.700000e+01
# 50%               1.450000e+02
# 75%               4.960000e+02
# max               1.000050e+06
#
#
#        total_fixture_watts
# count         5.183000e+03
# mean          8.248304e+03
# std           5.138861e+05
# min           0.000000e+00
# 25%           1.400000e+02
# 50%           3.320000e+02
# 75%           8.680000e+02
# max           3.699639e+07
#
#
#        total_fixture_watt_hours
# count              5.183000e+03
# mean               9.636667e+07
# std                4.977258e+08
# min                0.000000e+00
# 25%                6.374559e+06
# 50%                2.187810e+07
# 75%                7.082348e+07
# max                2.003750e+10
#
#
#        total_fixture_life_years
# count              5.183000e+03
# mean               3.004153e+03
# std                6.386603e+04
# min                0.000000e+00
# 25%                3.250252e+01
# 50%                1.052632e+02
# 75%                3.604499e+02
# max                2.118326e+06
#
#
#        total_item_watts
# count      5.183000e+03
# mean       8.679085e+04
# std        4.626062e+06
# min        0.000000e+00
# 25%        2.177500e+03
# 50%        6.395600e+03
# 75%        1.868150e+04
# max        3.329675e+08
#
#
#        sol_total_existing_count
# count               5425.000000
# mean                  46.892166
# std                  216.811908
# min                    1.000000
# 25%                    3.000000
# 50%                    8.000000
# 75%                   27.000000
# max                 7909.000000
#
#
#        total_product_count
# count          5425.000000
# mean             54.222673
# std             226.133532
# min               0.000000
# 25%               3.000000
# 50%              10.000000
# 75%              33.000000
# max            7059.000000
#
#
#        energy_savings_per_year
# count             5.425000e+03
# mean              8.476328e+06
# std               6.232114e+08
# min              -4.640000e+03
# 25%               8.414515e+02
# 50%               3.621822e+03
# 75%               1.154672e+04
# max               4.590240e+10
#
#
#        total_savings_per_year
# count            5.425000e+03
# mean             8.495115e+06
# std              6.232122e+08
# min              0.000000e+00
# 25%              9.593129e+02
# 50%              4.194590e+03
# 75%              1.300414e+04
# max              4.590240e+10
#
#
#             rebates
# count  1.095000e+03
# mean   1.320295e+04
# std    7.341061e+04
# min   -4.300000e+03
# 25%    1.200000e+03
# 50%    3.563200e+03
# 75%    1.133363e+04
# max    1.681374e+06
#
#
#        net_replacement_cost
# count          5.425000e+03
# mean           4.244899e+06
# std            3.094538e+08
# min            0.000000e+00
# 25%            3.758090e+03
# 50%            1.279451e+04
# 75%            3.594089e+04
# max            2.279273e+10
#
#
#            payback
# count  4287.000000
# mean      2.837940
# std       1.915617
# min       0.000000
# 25%       1.450000
# 50%       2.460000
# 75%       3.840000
# max       9.990000
#
#
#                ROI
# count  5341.000000
# mean           inf
# std            NaN
# min       0.000000
# 25%      17.492833
# 50%      34.205138
# 75%      61.332027
# max            inf

# %%
findata.mean()
# Out:
# project_id                   6.373631e+03
# option_id                    5.969140e+03
# option_calculation_id        5.975824e+03
# company_id                   4.121211e+02
# facility_type_id             3.607913e+01
# industry_type_id             2.263609e+03
# tax_rate_source              1.999630e+00
# finance_discount_rate        5.000000e+00
# tax_exempt                   3.870968e-03
# active                       1.000000e+00
# area_count                   6.025622e+00
# area_count_sum               1.226107e+04
# ave_annual_hours             4.249182e+03
# monday_ave_daily_hours       1.416117e+00
# tuesday_ave_daily_hours      1.418917e+00
# wednesday_ave_daily_hours    1.427601e+00
# thursday_ave_daily_hours     1.421139e+00
# friday_ave_daily_hours       1.421274e+00
# saturday_ave_daily_hours     9.112916e-01
# sunday_ave_daily_hours       5.206703e-01
# ave_weeks_per_year           6.101727e+00
# hour_type                    1.130502e+00
# max_kwh_cost                 6.554901e+00
# max_kwh_cost_simple          1.552282e-01
# existing_lighting_count      6.025622e+00
# total_watts_per_product      7.736680e+07
# ave_lm70                     1.662640e+04
# total_solution_count         6.025622e+00
# total_existing_quantity      6.441607e+03
# total_proposed_quantity      9.119975e+03
# total_replacement_count      8.287177e+02
# total_fixture_watts          8.248304e+03
# total_fixture_watt_hours     9.636667e+07
# total_fixture_life_years     3.004153e+03
# total_item_watts             8.679085e+04
# sol_total_existing_count     4.689217e+01
# total_product_count          5.422267e+01
# energy_savings_per_year      8.476328e+06
# total_savings_per_year       8.495115e+06
# rebates                      1.320295e+04
# net_replacement_cost         4.244899e+06
# payback                      2.837940e+00
# ROI                                   inf
# dtype: float64

# %%
findata.isnull().any()
# Out:
# project_id                   False
# option_id                    False
# option_calculation_id        False
# company_id                   False
# projects_name                False
# facility_type_id              True
# facility_type                 True
# industry_type_id              True
# name                         False
# started_at                   False
# finished_at                  False
# tax_rate_source               True
# finance_discount_rate        False
# tax_exempt                   False
# active                       False
# area_count                   False
# area_count_sum               False
# ave_annual_hours              True
# monday_ave_daily_hours        True
# tuesday_ave_daily_hours       True
# wednesday_ave_daily_hours     True
# thursday_ave_daily_hours      True
# friday_ave_daily_hours        True
# saturday_ave_daily_hours      True
# sunday_ave_daily_hours        True
# ave_weeks_per_year            True
# hour_type                     True
# max_kwh_cost                  True
# max_kwh_cost_simple           True
# existing_lighting_count      False
# total_watts_per_product      False
# ave_lm70                     False
# total_solution_count         False
# total_existing_quantity      False
# total_proposed_quantity      False
# total_replacement_count       True
# total_fixture_watts           True
# total_fixture_watt_hours      True
# total_fixture_life_years      True
# total_item_watts              True
# sol_total_existing_count     False
# total_product_count          False
# energy_savings_per_year      False
# total_savings_per_year       False
# rebates                       True
# net_replacement_cost         False
# payback                       True
# ROI                           True
# dtype: bool

# %%
findata.corr()
# Out:
#                            project_id  option_id  option_calculation_id  \
# project_id                   1.000000   0.977062               0.975389
# option_id                    0.977062   1.000000               0.995084
# option_calculation_id        0.975389   0.995084               1.000000
# company_id                   0.532563   0.552772               0.542828
# facility_type_id             0.037766   0.036972               0.036792
# industry_type_id            -0.072179  -0.081297              -0.076162
# tax_rate_source              0.025739   0.028479               0.023411
# finance_discount_rate             NaN        NaN                    NaN
# tax_exempt                   0.032261   0.034557               0.034525
# active                            NaN        NaN                    NaN
# area_count                  -0.007360   0.014144               0.006230
# area_count_sum               0.045375   0.057248               0.056244
# ave_annual_hours             0.020619   0.014204               0.017208
# monday_ave_daily_hours       0.388199   0.361081               0.364973
# tuesday_ave_daily_hours      0.390035   0.362746               0.366666
# wednesday_ave_daily_hours    0.391282   0.363803               0.367734
# thursday_ave_daily_hours     0.391036   0.363539               0.367474
# friday_ave_daily_hours       0.392490   0.364019               0.367969
# saturday_ave_daily_hours     0.327243   0.301412               0.304675
# sunday_ave_daily_hours       0.211018   0.196385               0.198359
# ave_weeks_per_year           0.417110   0.387489               0.391679
# hour_type                    0.405345   0.383099               0.387306
# max_kwh_cost                -0.036069  -0.036483              -0.041061
# max_kwh_cost_simple         -0.030709  -0.149339              -0.146815
# existing_lighting_count     -0.007360   0.014144               0.006230
# total_watts_per_product      0.046200   0.050631               0.050605
# ave_lm70                    -0.074553  -0.068444              -0.071874
# total_solution_count        -0.007360   0.014144               0.006230
# total_existing_quantity     -0.029375  -0.027692              -0.034385
# total_proposed_quantity     -0.031384  -0.029996              -0.037038
# total_replacement_count     -0.027915  -0.029863              -0.024511
# total_fixture_watts         -0.024993  -0.028187              -0.022824
# total_fixture_watt_hours    -0.012387  -0.006381              -0.001880
# total_fixture_life_years     0.048542   0.051668               0.052055
# total_item_watts            -0.025637  -0.028813              -0.023335
# sol_total_existing_count     0.010953   0.011056               0.017954
# total_product_count          0.000661   0.002647               0.006819
# energy_savings_per_year     -0.004310  -0.004233              -0.004501
# total_savings_per_year      -0.004303  -0.004226              -0.004494
# rebates                      0.011904   0.020689               0.020860
# net_replacement_cost        -0.004327  -0.004250              -0.004516
# payback                      0.108091   0.104526               0.101694
# ROI                          0.000234   0.004383               0.004288
#
#                            company_id  facility_type_id  industry_type_id  \
# project_id                   0.532563          0.037766         -0.072179
# option_id                    0.552772          0.036972         -0.081297
# option_calculation_id        0.542828          0.036792         -0.076162
# company_id                   1.000000          0.057632          0.028884
# facility_type_id             0.057632          1.000000         -0.059293
# industry_type_id             0.028884         -0.059293          1.000000
# tax_rate_source              0.026067          0.018600               NaN
# finance_discount_rate             NaN               NaN               NaN
# tax_exempt                   0.014624          0.051784          0.014102
# active                            NaN               NaN               NaN
# area_count                   0.046526          0.094869          0.024575
# area_count_sum               0.083361          0.127624          0.013325
# ave_annual_hours             0.050125         -0.077707          0.098642
# monday_ave_daily_hours       0.130535         -0.022895         -0.050315
# tuesday_ave_daily_hours      0.128654         -0.022864         -0.049954
# wednesday_ave_daily_hours    0.129176         -0.021732         -0.052204
# thursday_ave_daily_hours     0.130246         -0.022514         -0.050143
# friday_ave_daily_hours       0.131509         -0.024172         -0.053340
# saturday_ave_daily_hours     0.102376         -0.033482         -0.069736
# sunday_ave_daily_hours       0.040024          0.015798         -0.045882
# ave_weeks_per_year           0.156770         -0.022018         -0.067547
# hour_type                    0.161267         -0.019679         -0.075846
# max_kwh_cost                -0.015344          0.007919          0.035202
# max_kwh_cost_simple          0.183080          0.286359          0.041579
# existing_lighting_count      0.046526          0.094869          0.024575
# total_watts_per_product      0.068087          0.119479         -0.007998
# ave_lm70                    -0.037608          0.019092          0.071037
# total_solution_count         0.046526          0.094869          0.024575
# total_existing_quantity      0.018375          0.039949          0.102996
# total_proposed_quantity      0.005980          0.029389          0.082367
# total_replacement_count     -0.017049          0.071159          0.055254
# total_fixture_watts         -0.019424          0.069381         -0.023956
# total_fixture_watt_hours    -0.001425          0.078361          0.017481
# total_fixture_life_years     0.053185          0.085751         -0.016130
# total_item_watts            -0.019910          0.092687         -0.023623
# sol_total_existing_count     0.009371          0.043463          0.002647
# total_product_count          0.008654          0.053519         -0.003746
# energy_savings_per_year      0.009073         -0.010840          0.004726
# total_savings_per_year       0.009069         -0.009333         -0.002628
# rebates                      0.010033          0.097410          0.009657
# net_replacement_cost         0.009061          0.027375          0.028161
# payback                      0.093435         -0.009165          0.060174
# ROI                          0.004452         -0.013359          0.000656
#
#                            tax_rate_source  finance_discount_rate  tax_exempt  \
# project_id                        0.025739                    NaN    0.032261
# option_id                         0.028479                    NaN    0.034557
# option_calculation_id             0.023411                    NaN    0.034525
# company_id                        0.026067                    NaN    0.014624
# facility_type_id                  0.018600                    NaN    0.051784
# industry_type_id                       NaN                    NaN    0.014102
# tax_rate_source                   1.000000                    NaN    0.000849
# finance_discount_rate                  NaN                    NaN         NaN
# tax_exempt                        0.000849                    NaN    1.000000
# active                                 NaN                    NaN         NaN
# area_count                        0.010581                    NaN    0.040165
# area_count_sum                    0.001072                    NaN   -0.002501
# ave_annual_hours                       NaN                    NaN   -0.034572
# monday_ave_daily_hours                 NaN                    NaN   -0.009136
# tuesday_ave_daily_hours                NaN                    NaN   -0.009182
# wednesday_ave_daily_hours              NaN                    NaN   -0.009298
# thursday_ave_daily_hours               NaN                    NaN   -0.007360
# friday_ave_daily_hours                 NaN                    NaN   -0.007354
# saturday_ave_daily_hours               NaN                    NaN    0.002810
# sunday_ave_daily_hours                 NaN                    NaN    0.020840
# ave_weeks_per_year                     NaN                    NaN    0.013703
# hour_type                              NaN                    NaN   -0.006694
# max_kwh_cost                           NaN                    NaN   -0.001881
# max_kwh_cost_simple                    NaN                    NaN   -0.041085
# existing_lighting_count           0.010581                    NaN    0.040165
# total_watts_per_product           0.000829                    NaN   -0.003365
# ave_lm70                          0.012638                    NaN   -0.006934
# total_solution_count              0.010581                    NaN    0.040165
# total_existing_quantity           0.001575                    NaN    0.010474
# total_proposed_quantity           0.001111                    NaN    0.011429
# total_replacement_count           0.000779                    NaN    0.004950
# total_fixture_watts               0.000207                    NaN   -0.000333
# total_fixture_watt_hours          0.002697                    NaN    0.003780
# total_fixture_life_years          0.000655                    NaN    0.002166
# total_item_watts                  0.000223                    NaN   -0.000594
# sol_total_existing_count          0.002819                    NaN    0.054145
# total_product_count               0.003144                    NaN    0.108588
# energy_savings_per_year           0.000185                    NaN   -0.000847
# total_savings_per_year            0.000186                    NaN   -0.000849
# rebates                                NaN                    NaN    0.005595
# net_replacement_cost              0.000186                    NaN   -0.000842
# payback                                NaN                    NaN    0.002173
# ROI                               0.000192                    NaN   -0.000859
#
#                            active  ...  total_fixture_life_years  \
# project_id                    NaN  ...                  0.048542
# option_id                     NaN  ...                  0.051668
# option_calculation_id         NaN  ...                  0.052055
# company_id                    NaN  ...                  0.053185
# facility_type_id              NaN  ...                  0.085751
# industry_type_id              NaN  ...                 -0.016130
# tax_rate_source               NaN  ...                  0.000655
# finance_discount_rate         NaN  ...                       NaN
# tax_exempt                    NaN  ...                  0.002166
# active                        NaN  ...                       NaN
# area_count                    NaN  ...                  0.242865
# area_count_sum                NaN  ...                  0.410339
# ave_annual_hours              NaN  ...                 -0.038997
# monday_ave_daily_hours        NaN  ...                 -0.012417
# tuesday_ave_daily_hours       NaN  ...                 -0.012466
# wednesday_ave_daily_hours     NaN  ...                 -0.012511
# thursday_ave_daily_hours      NaN  ...                 -0.012494
# friday_ave_daily_hours        NaN  ...                 -0.012501
# saturday_ave_daily_hours      NaN  ...                 -0.011448
# sunday_ave_daily_hours        NaN  ...                 -0.008052
# ave_weeks_per_year            NaN  ...                 -0.013259
# hour_type                     NaN  ...                 -0.012333
# max_kwh_cost                  NaN  ...                 -0.001318
# max_kwh_cost_simple           NaN  ...                  0.083482
# existing_lighting_count       NaN  ...                  0.242865
# total_watts_per_product       NaN  ...                  0.363135
# ave_lm70                      NaN  ...                 -0.045225
# total_solution_count          NaN  ...                  0.242865
# total_existing_quantity       NaN  ...                  0.030899
# total_proposed_quantity       NaN  ...                  0.023073
# total_replacement_count       NaN  ...                  0.008877
# total_fixture_watts           NaN  ...                  0.000603
# total_fixture_watt_hours      NaN  ...                  0.022993
# total_fixture_life_years      NaN  ...                  1.000000
# total_item_watts              NaN  ...                  0.000317
# sol_total_existing_count      NaN  ...                  0.083606
# total_product_count           NaN  ...                  0.084098
# energy_savings_per_year       NaN  ...                  0.009613
# total_savings_per_year        NaN  ...                  0.006123
# rebates                       NaN  ...                 -0.001871
# net_replacement_cost          NaN  ...                  0.016215
# payback                       NaN  ...                 -0.002814
# ROI                           NaN  ...                 -0.000488
#
#                            total_item_watts  sol_total_existing_count  \
# project_id                        -0.025637                  0.010953
# option_id                         -0.028813                  0.011056
# option_calculation_id             -0.023335                  0.017954
# company_id                        -0.019910                  0.009371
# facility_type_id                   0.092687                  0.043463
# industry_type_id                  -0.023623                  0.002647
# tax_rate_source                    0.000223                  0.002819
# finance_discount_rate                   NaN                       NaN
# tax_exempt                        -0.000594                  0.054145
# active                                  NaN                       NaN
# area_count                        -0.008709                  0.219360
# area_count_sum                     0.000488                  0.115127
# ave_annual_hours                   0.023711                 -0.005140
# monday_ave_daily_hours             0.016500                  0.007800
# tuesday_ave_daily_hours            0.016475                  0.007577
# wednesday_ave_daily_hours          0.016068                  0.007432
# thursday_ave_daily_hours           0.016323                  0.007399
# friday_ave_daily_hours             0.015966                  0.007331
# saturday_ave_daily_hours           0.000876                 -0.008590
# sunday_ave_daily_hours            -0.007290                 -0.015950
# ave_weeks_per_year                 0.004130                 -0.003753
# hour_type                          0.008702                  0.011812
# max_kwh_cost                      -0.005281                 -0.005172
# max_kwh_cost_simple               -0.125685                 -0.085991
# existing_lighting_count           -0.008709                  0.219360
# total_watts_per_product            0.000604                  0.106571
# ave_lm70                          -0.006661                 -0.010921
# total_solution_count              -0.008709                  0.219360
# total_existing_quantity            0.005698                  0.320298
# total_proposed_quantity            0.003582                  0.251898
# total_replacement_count            0.013152                  0.055988
# total_fixture_watts                0.999722                  0.000218
# total_fixture_watt_hours           0.020724                  0.101385
# total_fixture_life_years           0.000317                  0.083606
# total_item_watts                   1.000000                  0.001130
# sol_total_existing_count           0.001130                  1.000000
# total_product_count                0.001397                  0.898417
# energy_savings_per_year            0.017307                 -0.002867
# total_savings_per_year             0.014340                 -0.002866
# rebates                            0.975018                  0.041886
# net_replacement_cost               0.019426                 -0.002827
# payback                            0.015165                  0.029671
# ROI                               -0.001003                  0.003058
#
#                            total_product_count  energy_savings_per_year  \
# project_id                            0.000661                -0.004310
# option_id                             0.002647                -0.004233
# option_calculation_id                 0.006819                -0.004501
# company_id                            0.008654                 0.009073
# facility_type_id                      0.053519                -0.010840
# industry_type_id                     -0.003746                 0.004726
# tax_rate_source                       0.003144                 0.000185
# finance_discount_rate                      NaN                      NaN
# tax_exempt                            0.108588                -0.000847
# active                                     NaN                      NaN
# area_count                            0.286734                -0.010554
# area_count_sum                        0.209812                -0.001066
# ave_annual_hours                     -0.009643                 0.001125
# monday_ave_daily_hours               -0.002402                -0.005044
# tuesday_ave_daily_hours              -0.002730                -0.005054
# wednesday_ave_daily_hours            -0.002791                -0.005071
# thursday_ave_daily_hours             -0.002937                -0.005059
# friday_ave_daily_hours               -0.003073                -0.005054
# saturday_ave_daily_hours             -0.021928                -0.004093
# sunday_ave_daily_hours               -0.019394                -0.002910
# ave_weeks_per_year                   -0.012696                -0.005400
# hour_type                             0.001522                -0.005399
# max_kwh_cost                         -0.005821                -0.000444
# max_kwh_cost_simple                  -0.055044                -0.095128
# existing_lighting_count               0.286734                -0.010554
# total_watts_per_product               0.202768                -0.000824
# ave_lm70                             -0.002216                -0.024024
# total_solution_count                  0.286734                -0.010554
# total_existing_quantity               0.457727                -0.001575
# total_proposed_quantity               0.444633                -0.001108
# total_replacement_count               0.074489                 0.209309
# total_fixture_watts                   0.000198                -0.002013
# total_fixture_watt_hours              0.110550                 0.781128
# total_fixture_life_years              0.084098                 0.009613
# total_item_watts                      0.001397                 0.017307
# sol_total_existing_count              0.898417                -0.002867
# total_product_count                   1.000000                -0.003190
# energy_savings_per_year              -0.003190                 1.000000
# total_savings_per_year               -0.003187                 0.999998
# rebates                               0.033894                 0.979197
# net_replacement_cost                 -0.003148                 1.000000
# payback                               0.031779                -0.018655
# ROI                                   0.002446                -0.000191
#
#                            total_savings_per_year   rebates  \
# project_id                              -0.004303  0.011904
# option_id                               -0.004226  0.020689
# option_calculation_id                   -0.004494  0.020860
# company_id                               0.009069  0.010033
# facility_type_id                        -0.009333  0.097410
# industry_type_id                        -0.002628  0.009657
# tax_rate_source                          0.000186       NaN
# finance_discount_rate                         NaN       NaN
# tax_exempt                              -0.000849  0.005595
# active                                        NaN       NaN
# area_count                              -0.010573  0.011964
# area_count_sum                          -0.001069 -0.000296
# ave_annual_hours                         0.001129  0.023680
# monday_ave_daily_hours                  -0.005041 -0.011298
# tuesday_ave_daily_hours                 -0.005052 -0.012036
# wednesday_ave_daily_hours               -0.005069 -0.011972
# thursday_ave_daily_hours                -0.005057 -0.011775
# friday_ave_daily_hours                  -0.005052 -0.011782
# saturday_ave_daily_hours                -0.004086 -0.013666
# sunday_ave_daily_hours                  -0.002896 -0.005986
# ave_weeks_per_year                      -0.005329 -0.021682
# hour_type                               -0.005335 -0.026773
# max_kwh_cost                            -0.000444  0.004531
# max_kwh_cost_simple                     -0.067290 -0.104205
# existing_lighting_count                 -0.010573  0.011964
# total_watts_per_product                 -0.000826  0.003833
# ave_lm70                                -0.024027 -0.021857
# total_solution_count                    -0.010573  0.011964
# total_existing_quantity                 -0.001576  0.053391
# total_proposed_quantity                 -0.001109  0.036403
# total_replacement_count                  0.163062  0.574259
# total_fixture_watts                     -0.001878  0.015986
# total_fixture_watt_hours                 0.660186  0.963458
# total_fixture_life_years                 0.006123 -0.001871
# total_item_watts                         0.014340  0.975018
# sol_total_existing_count                -0.002866  0.041886
# total_product_count                     -0.003187  0.033894
# energy_savings_per_year                  0.999998  0.979197
# total_savings_per_year                   1.000000  0.976792
# rebates                                  0.976792  1.000000
# net_replacement_cost                     0.999998  0.926183
# payback                                 -0.018700 -0.045000
# ROI                                     -0.000191 -0.003482
#
#                            net_replacement_cost   payback       ROI
# project_id                            -0.004327  0.108091  0.000234
# option_id                             -0.004250  0.104526  0.004383
# option_calculation_id                 -0.004516  0.101694  0.004288
# company_id                             0.009061  0.093435  0.004452
# facility_type_id                       0.027375 -0.009165 -0.013359
# industry_type_id                       0.028161  0.060174  0.000656
# tax_rate_source                        0.000186       NaN  0.000192
# finance_discount_rate                       NaN       NaN       NaN
# tax_exempt                            -0.000842  0.002173 -0.000859
# active                                      NaN       NaN       NaN
# area_count                            -0.010513  0.076204 -0.004418
# area_count_sum                        -0.001050 -0.002561 -0.001002
# ave_annual_hours                       0.001141 -0.136092  0.010346
# monday_ave_daily_hours                -0.005057  0.048645 -0.005159
# tuesday_ave_daily_hours               -0.005067  0.043292 -0.005170
# wednesday_ave_daily_hours             -0.005084  0.046815 -0.005187
# thursday_ave_daily_hours              -0.005073  0.042134 -0.005175
# friday_ave_daily_hours                -0.005068  0.049145 -0.005171
# saturday_ave_daily_hours              -0.004108  0.006855 -0.004181
# sunday_ave_daily_hours                -0.002920 -0.019524 -0.002949
# ave_weeks_per_year                    -0.005417  0.074454 -0.005521
# hour_type                             -0.005413  0.062492 -0.005522
# max_kwh_cost                          -0.000444  0.011677 -0.000457
# max_kwh_cost_simple                   -0.135668  0.022677 -0.031798
# existing_lighting_count               -0.010513  0.076204 -0.004418
# total_watts_per_product               -0.000810 -0.003408 -0.000854
# ave_lm70                              -0.024029  0.023820  0.001673
# total_solution_count                  -0.010513  0.076204 -0.004418
# total_existing_quantity               -0.001413  0.034274 -0.000837
# total_proposed_quantity               -0.001009  0.018083 -0.000748
# total_replacement_count                0.537979  0.013443 -0.000484
# total_fixture_watts                   -0.001865  0.053172  0.011318
# total_fixture_watt_hours               0.877842 -0.004364  0.000031
# total_fixture_life_years               0.016215 -0.002814 -0.000488
# total_item_watts                       0.019426  0.015165 -0.001003
# sol_total_existing_count              -0.002827  0.029671  0.003058
# total_product_count                   -0.003148  0.031779  0.002446
# energy_savings_per_year                1.000000 -0.018655 -0.000191
# total_savings_per_year                 0.999998 -0.018700 -0.000191
# rebates                                0.926183 -0.045000 -0.003482
# net_replacement_cost                   1.000000 -0.018606 -0.000193
# payback                               -0.018606  1.000000 -0.023202
# ROI                                   -0.000193 -0.023202  1.000000
#
# [43 rows x 43 columns]

# %%
mean_value_mc=findata['max_kwh_cost'].mean()
findata['max_kwh_cost']=findata['max_kwh_cost'].fillna(mean_value_mc)
findata['max_kwh_cost']
# Out:
# 0       6.554901
# 1       0.100000
# 2       6.554901
# 3       0.100000
# 4       0.100000
#           ...
# 5420    6.554901
# 5421    0.100000
# 5422    0.120000
# 5423    0.100000
# 5424    0.080000
# Name: max_kwh_cost, Length: 5425, dtype: float64

# %%
mean_value_mcs=findata['max_kwh_cost_simple'].mean()
findata['max_kwh_cost_simple']=findata['max_kwh_cost_simple'].fillna(mean_value_mcs)
findata['max_kwh_cost_simple']
# Out:
# 0       0.155228
# 1       0.155228
# 2       0.155228
# 3       0.155228
# 4       0.155228
#           ...
# 5420    0.085000
# 5421    0.155228
# 5422    0.155228
# 5423    0.155228
# 5424    0.155228
# Name: max_kwh_cost_simple, Length: 5425, dtype: float64

# %%
mean_value_trc=findata['total_replacement_count'].mean()
findata['total_replacement_count']=findata['total_replacement_count'].fillna(mean_value_trc)
findata['total_replacement_count']
# Out:
# 0       56.0
# 1       10.0
# 2       43.0
# 3        1.0
# 4       80.0
#         ...
# 5420    58.0
# 5421     9.0
# 5422    61.0
# 5423    35.0
# 5424     2.0
# Name: total_replacement_count, Length: 5425, dtype: float64

# %%
mean_value_tfw=findata['total_fixture_watts'].mean()
findata['total_fixture_watts']=findata['total_fixture_watts'].fillna(mean_value_tfw)
findata['total_fixture_watts']
# Out:
# 0         0.0
# 1        13.0
# 2       600.0
# 3         0.0
# 4        83.0
#         ...
# 5420    569.0
# 5421     30.0
# 5422     30.0
# 5423    150.0
# 5424     36.0
# Name: total_fixture_watts, Length: 5425, dtype: float64

# %%
mean_value_tfwh=findata['total_fixture_watt_hours'].mean()
findata['total_fixture_watt_hours']=findata['total_fixture_watt_hours'].fillna(mean_value_tfwh)
findata['total_fixture_watt_hours']
# Out:
# 0              0.0
# 1         130000.0
# 2              0.0
# 3              0.0
# 4        2097888.0
#            ...
# 5420    20786640.0
# 5421      449280.0
# 5422     7600320.0
# 5423    14458500.0
# 5424      360000.0
# Name: total_fixture_watt_hours, Length: 5425, dtype: float64

# %%
mean_value_tfly=findata['total_fixture_life_years'].mean()
findata['total_fixture_life_years']=findata['total_fixture_life_years'].fillna(mean_value_tfly)
findata['total_fixture_life_years']
# Out:
# 0         0.000000
# 1        50.000000
# 2         0.000000
# 3         0.000000
# 4       180.288462
#            ...
# 5420    345.053272
# 5421     30.048077
# 5422      4.578755
# 5423     18.155410
# 5424     16.000000
# Name: total_fixture_life_years, Length: 5425, dtype: float64

# %%
mean_value_tiw=findata['total_item_watts'].mean()
findata['total_item_watts']=findata['total_item_watts'].fillna(mean_value_tiw)
findata['total_item_watts']
# Out:
# 0           0.0
# 1         130.0
# 2       12900.0
# 3           0.0
# 4        1681.0
#          ...
# 5420     5278.0
# 5421      135.0
# 5422     1740.0
# 5423     5250.0
# 5424       72.0
# Name: total_item_watts, Length: 5425, dtype: float64

# %%
mean_value_r=findata['rebates'].mean()
findata['rebates']=findata['rebates'].fillna(mean_value_r)
findata['rebates']
# Out:
# 0          18.000000
# 1       13202.949855
# 2       13202.949855
# 3       13202.949855
# 4       13202.949855
#             ...
# 5420    13202.949855
# 5421      250.000000
# 5422    13202.949855
# 5423     6869.000000
# 5424    13202.949855
# Name: rebates, Length: 5425, dtype: float64

# %%
mean_value_p=findata['payback'].mean()
findata['payback']=findata['payback'].fillna(mean_value_p)
findata['payback']
# Out:
# 0       2.83794
# 1       0.34000
# 2       2.83794
# 3       2.83794
# 4       2.83794
#          ...
# 5420    0.91000
# 5421    4.88000
# 5422    0.00000
# 5423    1.67000
# 5424    8.13000
# Name: payback, Length: 5425, dtype: float64

# %%
mean_value_roi=findata['ROI'].mean()
findata['ROI']=findata['ROI'].fillna(mean_value_roi)
findata['ROI']
# Out:
# 0         0.000000
# 1       297.198880
# 2         0.000000
# 3              inf
# 4        12.304965
#            ...
# 5420    109.842581
# 5421     19.006281
# 5422           inf
# 5423     58.857255
# 5424     10.700163
# Name: ROI, Length: 5425, dtype: float64

# %%
mean_value_aah=findata['ave_annual_hours'].mean()
findata['ave_annual_hours']=findata['ave_annual_hours'].fillna(mean_value_aah)
findata['ave_annual_hours']
# Out:
# 0       4880.000000
# 1       1000.000000
# 2       4249.181784
# 3       3727.000000
# 4       3727.000000
#            ...
# 5420    4380.000000
# 5421    8760.000000
# 5422    4368.000000
# 5423    4249.181784
# 5424    5000.000000
# Name: ave_annual_hours, Length: 5425, dtype: float64

# %%
mean_value_monday=findata['monday_ave_daily_hours'].mean()
findata['monday_ave_daily_hours']=findata['monday_ave_daily_hours'].fillna(mean_value_monday)
findata['monday_ave_daily_hours']
# Out:
# 0       0.000000
# 1       0.000000
# 2       1.416117
# 3       0.000000
# 4       0.000000
#           ...
# 5420    9.500000
# 5421    5.000000
# 5422    0.000000
# 5423    9.000000
# 5424    0.000000
# Name: monday_ave_daily_hours, Length: 5425, dtype: float64

# %%
mean_value_tuesday=findata['tuesday_ave_daily_hours'].mean()
findata['tuesday_ave_daily_hours']=findata['tuesday_ave_daily_hours'].fillna(mean_value_tuesday)
findata['tuesday_ave_daily_hours']
# Out:
# 0       0.000000
# 1       0.000000
# 2       1.418917
# 3       0.000000
# 4       0.000000
#           ...
# 5420    9.500000
# 5421    5.000000
# 5422    0.000000
# 5423    9.000000
# 5424    0.000000
# Name: tuesday_ave_daily_hours, Length: 5425, dtype: float64

# %%
mean_value_wednesday=findata['wednesday_ave_daily_hours'].mean()
findata['wednesday_ave_daily_hours']=findata['wednesday_ave_daily_hours'].fillna(mean_value_wednesday)
findata['wednesday_ave_daily_hours']
# Out:
# 0       0.000000
# 1       0.000000
# 2       1.427601
# 3       0.000000
# 4       0.000000
#           ...
# 5420    9.500000
# 5421    5.000000
# 5422    0.000000
# 5423    9.000000
# 5424    0.000000
# Name: wednesday_ave_daily_hours, Length: 5425, dtype: float64

# %%
data_without_str= ['project_id', 'option_id', 'option_calculation_id', 'company_id',
       'facility_type_id', 'industry_type_id', 'tax_rate_source',
       'finance_discount_rate', 'area_count', 'area_count_sum',
       'ave_annual_hours', 'monday_ave_daily_hours', 'tuesday_ave_daily_hours',
       'wednesday_ave_daily_hours', 'thursday_ave_daily_hours',
       'friday_ave_daily_hours', 'saturday_ave_daily_hours',
       'sunday_ave_daily_hours', 'ave_weeks_per_year', 'hour_type',
       'max_kwh_cost', 'max_kwh_cost_simple', 'existing_lighting_count',
       'total_watts_per_product', 'ave_lm70', 'total_solution_count',
       'total_existing_quantity', 'total_proposed_quantity',
       'total_replacement_count', 'total_fixture_watts',
       'total_fixture_watt_hours', 'total_fixture_life_years',
       'total_item_watts', 'sol_total_existing_count', 'total_product_count',
       'energy_savings_per_year', 'total_savings_per_year', 'rebates',
       'net_replacement_cost', 'payback', 'ROI']

# %%
mean_value_thursday=findata['thursday_ave_daily_hours'].mean()
findata['thursday_ave_daily_hours']=findata['thursday_ave_daily_hours'].fillna(mean_value_thursday)
findata['thursday_ave_daily_hours']
# Out:
# 0       0.000000
# 1       0.000000
# 2       1.421139
# 3       0.000000
# 4       0.000000
#           ...
# 5420    9.500000
# 5421    5.000000
# 5422    0.000000
# 5423    9.000000
# 5424    0.000000
# Name: thursday_ave_daily_hours, Length: 5425, dtype: float64

# %%
mean_value_friday=findata['friday_ave_daily_hours'].mean()
findata['friday_ave_daily_hours']=findata['friday_ave_daily_hours'].fillna(mean_value_friday)
findata['friday_ave_daily_hours']
# Out:
# 0       0.000000
# 1       0.000000
# 2       1.421274
# 3       0.000000
# 4       0.000000
#           ...
# 5420    9.500000
# 5421    6.000000
# 5422    0.000000
# 5423    9.000000
# 5424    0.000000
# Name: friday_ave_daily_hours, Length: 5425, dtype: float64

# %%
mean_value_saturday=findata['saturday_ave_daily_hours'].mean()
findata['saturday_ave_daily_hours']=findata['saturday_ave_daily_hours'].fillna(mean_value_saturday)
findata['saturday_ave_daily_hours']
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.911292
# 3       0.000000
# 4       0.000000
#           ...
# 5420    0.000000
# 5421    6.000000
# 5422    0.000000
# 5423    9.000000
# 5424    0.000000
# Name: saturday_ave_daily_hours, Length: 5425, dtype: float64

# %%
mean_value_sunday=findata['sunday_ave_daily_hours'].mean()
findata['sunday_ave_daily_hours']=findata['sunday_ave_daily_hours'].fillna(mean_value_sunday)
findata['sunday_ave_daily_hours']
# Out:
# 0       0.00000
# 1       0.00000
# 2       0.52067
# 3       0.00000
# 4       0.00000
#          ...
# 5420    0.00000
# 5421    0.00000
# 5422    0.00000
# 5423    0.00000
# 5424    0.00000
# Name: sunday_ave_daily_hours, Length: 5425, dtype: float64

# %%
mean_value_avg=findata['ave_weeks_per_year'].mean()
findata['ave_weeks_per_year']=findata['ave_weeks_per_year'].fillna(mean_value_avg)
findata['ave_weeks_per_year']
# Out:
# 0        0.000000
# 1        0.000000
# 2        6.101727
# 3        0.000000
# 4        0.000000
#           ...
# 5420    52.000000
# 5421    26.000000
# 5422     0.000000
# 5423    51.000000
# 5424     0.000000
# Name: ave_weeks_per_year, Length: 5425, dtype: float64

# %%
findata
# Out:
#       project_id  option_id  option_calculation_id  company_id  \
# 0              3          8                   1235           5
# 1              8        290                   1398           7
# 2             11         92                   1221          15
# 3             15         21                   1782          19
# 4             15        928                   1781          19
# ...          ...        ...                    ...         ...
# 5420       12131      10277                  10273        1050
# 5421       12132      10278                  10274         155
# 5422       12137      10284                  10280         943
# 5423       12138      10286                  10282         118
# 5424       12143      10292                  10288         454
#
#                                        projects_name  facility_type_id  \
# 0                                  Eagle Enterprises               NaN
# 1                                     Acme Warehouse               NaN
# 2                                   Golden Spoon_257              19.0
# 3     Demo Project - updated and synced name - again               NaN
# 4     Demo Project - updated and synced name - again               NaN
# ...                                              ...               ...
# 5420                          Boise Office Building                NaN
# 5421                             L.E.D. Test Project              40.0
# 5422                        Central Arizona Freight               62.0
# 5423                               Leavitt Machinery              25.0
# 5424                                     jacob test2               NaN
#
#                       facility_type  industry_type_id  \
# 0                               NaN            2252.0
# 1                               NaN               NaN
# 2             Fast Food Restaurants               NaN
# 3                               NaN            2336.0
# 4                               NaN            2336.0
# ...                             ...               ...
# 5420                            NaN               NaN
# 5421  Office (General Office Types)               NaN
# 5422   Warehouse (Not Refrigerated)               NaN
# 5423           Industrial - 1 Shift               NaN
# 5424                            NaN               NaN
#
#                               name started_at  ... total_fixture_life_years  \
# 0     Trantow, Langworth and Moore    34:45.0  ...                 0.000000
# 1              Bartoletti and Sons    28:04.8  ...                50.000000
# 2      Anderson, Shields and Hyatt    43:31.8  ...                 0.000000
# 3     Blanda, Stiedemann and Kiehn    40:38.1  ...                 0.000000
# 4     Blanda, Stiedemann and Kiehn    55:33.8  ...               180.288462
# ...                            ...        ...  ...                      ...
# 5420                   Wolf-Hickle    40:23.0  ...               345.053272
# 5421    Ritchie, Kautzer and Berge    40:23.0  ...                30.048077
# 5422                Runolfsson Inc    40:26.2  ...                 4.578755
# 5423    Batz, Keebler and Schiller    40:27.6  ...                18.155410
# 5424                Aufderhar-Huel    40:29.2  ...                16.000000
#
#       total_item_watts  sol_total_existing_count  total_product_count  \
# 0                  0.0                         4                    4
# 1                130.0                         1                    1
# 2              12900.0                         2                    2
# 3                  0.0                         6                    6
# 4               1681.0                        12                   10
# ...                ...                       ...                  ...
# 5420            5278.0                        12                   12
# 5421             135.0                         2                    2
# 5422            1740.0                         2                    2
# 5423            5250.0                         1                    1
# 5424              72.0                         1                    1
#
#       energy_savings_per_year  total_savings_per_year       rebates  \
# 0                0.000000e+00            0.000000e+00     18.000000
# 1                8.700000e+01            3.536667e+02  13202.949855
# 2                0.000000e+00            0.000000e+00  13202.949855
# 3                6.220000e-15            6.220000e-15  13202.949855
# 4                9.665942e+02            1.044594e+03  13202.949855
# ...                       ...                     ...           ...
# 5420             7.362246e+03            8.698787e+03  13202.949855
# 5421             1.857024e+02            1.778421e+02    250.000000
# 5422             9.120384e+02            9.120384e+02  13202.949855
# 5423             3.026646e+03            3.026646e+03   6869.000000
# 5424             3.680000e+01            3.680000e+01  13202.949855
#
#       net_replacement_cost  payback         ROI
# 0                 2.130000  2.83794    0.000000
# 1               119.000000  0.34000  297.198880
# 2             13330.000000  2.83794    0.000000
# 3                 0.000000  2.83794         inf
# 4              8489.209400  2.83794   12.304965
# ...                    ...      ...         ...
# 5420           7919.321000  0.91000  109.842581
# 5421            935.701564  4.88000   19.006281
# 5422              0.000000  0.00000         inf
# 5423           5142.349937  1.67000   58.857255
# 5424            343.920000  8.13000   10.700163
#
# [5425 rows x 48 columns]

# %%
findata = findata.replace(np.nan,0)
findata
# Out:
#       project_id  option_id  option_calculation_id  company_id  \
# 0              3          8                   1235           5
# 1              8        290                   1398           7
# 2             11         92                   1221          15
# 3             15         21                   1782          19
# 4             15        928                   1781          19
# ...          ...        ...                    ...         ...
# 5420       12131      10277                  10273        1050
# 5421       12132      10278                  10274         155
# 5422       12137      10284                  10280         943
# 5423       12138      10286                  10282         118
# 5424       12143      10292                  10288         454
#
#                                        projects_name  facility_type_id  \
# 0                                  Eagle Enterprises               0.0
# 1                                     Acme Warehouse               0.0
# 2                                   Golden Spoon_257              19.0
# 3     Demo Project - updated and synced name - again               0.0
# 4     Demo Project - updated and synced name - again               0.0
# ...                                              ...               ...
# 5420                          Boise Office Building                0.0
# 5421                             L.E.D. Test Project              40.0
# 5422                        Central Arizona Freight               62.0
# 5423                               Leavitt Machinery              25.0
# 5424                                     jacob test2               0.0
#
#                       facility_type  industry_type_id  \
# 0                                 0            2252.0
# 1                                 0               0.0
# 2             Fast Food Restaurants               0.0
# 3                                 0            2336.0
# 4                                 0            2336.0
# ...                             ...               ...
# 5420                              0               0.0
# 5421  Office (General Office Types)               0.0
# 5422   Warehouse (Not Refrigerated)               0.0
# 5423           Industrial - 1 Shift               0.0
# 5424                              0               0.0
#
#                               name started_at  ... total_fixture_life_years  \
# 0     Trantow, Langworth and Moore    34:45.0  ...                 0.000000
# 1              Bartoletti and Sons    28:04.8  ...                50.000000
# 2      Anderson, Shields and Hyatt    43:31.8  ...                 0.000000
# 3     Blanda, Stiedemann and Kiehn    40:38.1  ...                 0.000000
# 4     Blanda, Stiedemann and Kiehn    55:33.8  ...               180.288462
# ...                            ...        ...  ...                      ...
# 5420                   Wolf-Hickle    40:23.0  ...               345.053272
# 5421    Ritchie, Kautzer and Berge    40:23.0  ...                30.048077
# 5422                Runolfsson Inc    40:26.2  ...                 4.578755
# 5423    Batz, Keebler and Schiller    40:27.6  ...                18.155410
# 5424                Aufderhar-Huel    40:29.2  ...                16.000000
#
#       total_item_watts  sol_total_existing_count  total_product_count  \
# 0                  0.0                         4                    4
# 1                130.0                         1                    1
# 2              12900.0                         2                    2
# 3                  0.0                         6                    6
# 4               1681.0                        12                   10
# ...                ...                       ...                  ...
# 5420            5278.0                        12                   12
# 5421             135.0                         2                    2
# 5422            1740.0                         2                    2
# 5423            5250.0                         1                    1
# 5424              72.0                         1                    1
#
#       energy_savings_per_year  total_savings_per_year       rebates  \
# 0                0.000000e+00            0.000000e+00     18.000000
# 1                8.700000e+01            3.536667e+02  13202.949855
# 2                0.000000e+00            0.000000e+00  13202.949855
# 3                6.220000e-15            6.220000e-15  13202.949855
# 4                9.665942e+02            1.044594e+03  13202.949855
# ...                       ...                     ...           ...
# 5420             7.362246e+03            8.698787e+03  13202.949855
# 5421             1.857024e+02            1.778421e+02    250.000000
# 5422             9.120384e+02            9.120384e+02  13202.949855
# 5423             3.026646e+03            3.026646e+03   6869.000000
# 5424             3.680000e+01            3.680000e+01  13202.949855
#
#       net_replacement_cost  payback         ROI
# 0                 2.130000  2.83794    0.000000
# 1               119.000000  0.34000  297.198880
# 2             13330.000000  2.83794    0.000000
# 3                 0.000000  2.83794         inf
# 4              8489.209400  2.83794   12.304965
# ...                    ...      ...         ...
# 5420           7919.321000  0.91000  109.842581
# 5421            935.701564  4.88000   19.006281
# 5422              0.000000  0.00000         inf
# 5423           5142.349937  1.67000   58.857255
# 5424            343.920000  8.13000   10.700163
#
# [5425 rows x 48 columns]

# %%
ROI_inf= findata['ROI'].median()
ROI=findata['ROI']
findata['ROI']=ROI.replace(np.inf,ROI_inf)
findata
# Out:
#       project_id  option_id  option_calculation_id  company_id  \
# 0              3          8                   1235           5
# 1              8        290                   1398           7
# 2             11         92                   1221          15
# 3             15         21                   1782          19
# 4             15        928                   1781          19
# ...          ...        ...                    ...         ...
# 5420       12131      10277                  10273        1050
# 5421       12132      10278                  10274         155
# 5422       12137      10284                  10280         943
# 5423       12138      10286                  10282         118
# 5424       12143      10292                  10288         454
#
#                                        projects_name  facility_type_id  \
# 0                                  Eagle Enterprises               0.0
# 1                                     Acme Warehouse               0.0
# 2                                   Golden Spoon_257              19.0
# 3     Demo Project - updated and synced name - again               0.0
# 4     Demo Project - updated and synced name - again               0.0
# ...                                              ...               ...
# 5420                          Boise Office Building                0.0
# 5421                             L.E.D. Test Project              40.0
# 5422                        Central Arizona Freight               62.0
# 5423                               Leavitt Machinery              25.0
# 5424                                     jacob test2               0.0
#
#                       facility_type  industry_type_id  \
# 0                                 0            2252.0
# 1                                 0               0.0
# 2             Fast Food Restaurants               0.0
# 3                                 0            2336.0
# 4                                 0            2336.0
# ...                             ...               ...
# 5420                              0               0.0
# 5421  Office (General Office Types)               0.0
# 5422   Warehouse (Not Refrigerated)               0.0
# 5423           Industrial - 1 Shift               0.0
# 5424                              0               0.0
#
#                               name started_at  ... total_fixture_life_years  \
# 0     Trantow, Langworth and Moore    34:45.0  ...                 0.000000
# 1              Bartoletti and Sons    28:04.8  ...                50.000000
# 2      Anderson, Shields and Hyatt    43:31.8  ...                 0.000000
# 3     Blanda, Stiedemann and Kiehn    40:38.1  ...                 0.000000
# 4     Blanda, Stiedemann and Kiehn    55:33.8  ...               180.288462
# ...                            ...        ...  ...                      ...
# 5420                   Wolf-Hickle    40:23.0  ...               345.053272
# 5421    Ritchie, Kautzer and Berge    40:23.0  ...                30.048077
# 5422                Runolfsson Inc    40:26.2  ...                 4.578755
# 5423    Batz, Keebler and Schiller    40:27.6  ...                18.155410
# 5424                Aufderhar-Huel    40:29.2  ...                16.000000
#
#       total_item_watts  sol_total_existing_count  total_product_count  \
# 0                  0.0                         4                    4
# 1                130.0                         1                    1
# 2              12900.0                         2                    2
# 3                  0.0                         6                    6
# 4               1681.0                        12                   10
# ...                ...                       ...                  ...
# 5420            5278.0                        12                   12
# 5421             135.0                         2                    2
# 5422            1740.0                         2                    2
# 5423            5250.0                         1                    1
# 5424              72.0                         1                    1
#
#       energy_savings_per_year  total_savings_per_year       rebates  \
# 0                0.000000e+00            0.000000e+00     18.000000
# 1                8.700000e+01            3.536667e+02  13202.949855
# 2                0.000000e+00            0.000000e+00  13202.949855
# 3                6.220000e-15            6.220000e-15  13202.949855
# 4                9.665942e+02            1.044594e+03  13202.949855
# ...                       ...                     ...           ...
# 5420             7.362246e+03            8.698787e+03  13202.949855
# 5421             1.857024e+02            1.778421e+02    250.000000
# 5422             9.120384e+02            9.120384e+02  13202.949855
# 5423             3.026646e+03            3.026646e+03   6869.000000
# 5424             3.680000e+01            3.680000e+01  13202.949855
#
#       net_replacement_cost  payback         ROI
# 0                 2.130000  2.83794    0.000000
# 1               119.000000  0.34000  297.198880
# 2             13330.000000  2.83794    0.000000
# 3                 0.000000  2.83794   34.785931
# 4              8489.209400  2.83794   12.304965
# ...                    ...      ...         ...
# 5420           7919.321000  0.91000  109.842581
# 5421            935.701564  4.88000   19.006281
# 5422              0.000000  0.00000   34.785931
# 5423           5142.349937  1.67000   58.857255
# 5424            343.920000  8.13000   10.700163
#
# [5425 rows x 48 columns]

# %%
findata.isnull().any()
# Out:
# project_id                   False
# option_id                    False
# option_calculation_id        False
# company_id                   False
# projects_name                False
# facility_type_id             False
# facility_type                False
# industry_type_id             False
# name                         False
# started_at                   False
# finished_at                  False
# tax_rate_source              False
# finance_discount_rate        False
# tax_exempt                   False
# active                       False
# area_count                   False
# area_count_sum               False
# ave_annual_hours             False
# monday_ave_daily_hours       False
# tuesday_ave_daily_hours      False
# wednesday_ave_daily_hours    False
# thursday_ave_daily_hours     False
# friday_ave_daily_hours       False
# saturday_ave_daily_hours     False
# sunday_ave_daily_hours       False
# ave_weeks_per_year           False
# hour_type                    False
# max_kwh_cost                 False
# max_kwh_cost_simple          False
# existing_lighting_count      False
# total_watts_per_product      False
# ave_lm70                     False
# total_solution_count         False
# total_existing_quantity      False
# total_proposed_quantity      False
# total_replacement_count      False
# total_fixture_watts          False
# total_fixture_watt_hours     False
# total_fixture_life_years     False
# total_item_watts             False
# sol_total_existing_count     False
# total_product_count          False
# energy_savings_per_year      False
# total_savings_per_year       False
# rebates                      False
# net_replacement_cost         False
# payback                      False
# ROI                          False
# dtype: bool

# %%
findata.isna().any()
# Out:
# project_id                   False
# option_id                    False
# option_calculation_id        False
# company_id                   False
# projects_name                False
# facility_type_id             False
# facility_type                False
# industry_type_id             False
# name                         False
# started_at                   False
# finished_at                  False
# tax_rate_source              False
# finance_discount_rate        False
# tax_exempt                   False
# active                       False
# area_count                   False
# area_count_sum               False
# ave_annual_hours             False
# monday_ave_daily_hours       False
# tuesday_ave_daily_hours      False
# wednesday_ave_daily_hours    False
# thursday_ave_daily_hours     False
# friday_ave_daily_hours       False
# saturday_ave_daily_hours     False
# sunday_ave_daily_hours       False
# ave_weeks_per_year           False
# hour_type                    False
# max_kwh_cost                 False
# max_kwh_cost_simple          False
# existing_lighting_count      False
# total_watts_per_product      False
# ave_lm70                     False
# total_solution_count         False
# total_existing_quantity      False
# total_proposed_quantity      False
# total_replacement_count      False
# total_fixture_watts          False
# total_fixture_watt_hours     False
# total_fixture_life_years     False
# total_item_watts             False
# sol_total_existing_count     False
# total_product_count          False
# energy_savings_per_year      False
# total_savings_per_year       False
# rebates                      False
# net_replacement_cost         False
# payback                      False
# ROI                          False
# dtype: bool

# %%
new_dataframe = findata.filter(['finance_discount_rate', 
       'area_count', 'area_count_sum', 'ave_annual_hours',
       'monday_ave_daily_hours', 'tuesday_ave_daily_hours',
       'wednesday_ave_daily_hours', 'thursday_ave_daily_hours',
       'friday_ave_daily_hours', 'saturday_ave_daily_hours',
       'sunday_ave_daily_hours', 'ave_weeks_per_year', 
       'max_kwh_cost', 'max_kwh_cost_simple', 'existing_lighting_count',
       'total_watts_per_product', 'ave_lm70',
       'total_existing_quantity', 'total_proposed_quantity',
       'total_replacement_count', 'total_fixture_watts',
       'total_fixture_watt_hours', 'total_fixture_life_years',
       'total_item_watts', 'sol_total_existing_count', 'total_product_count',
       'energy_savings_per_year', 'total_savings_per_year', 'rebates',
       'net_replacement_cost', 'payback', 'ROI'], axis=1)

new_dataframe_1 = new_dataframe.filter(['finance_discount_rate', 
       'area_count', 'area_count_sum', 'ave_annual_hours',
       'monday_ave_daily_hours', 'tuesday_ave_daily_hours',
       'wednesday_ave_daily_hours', 'thursday_ave_daily_hours',
       'friday_ave_daily_hours', 'saturday_ave_daily_hours',
       'sunday_ave_daily_hours', 'ave_weeks_per_year', 
       'max_kwh_cost', 'max_kwh_cost_simple', 'existing_lighting_count',
       'total_watts_per_product', 'ave_lm70',
       'total_existing_quantity', 'total_proposed_quantity',
       'total_replacement_count', 'total_fixture_watts',
       'total_fixture_watt_hours', 'total_fixture_life_years',
       'total_item_watts', 'sol_total_existing_count', 'total_product_count',
       'energy_savings_per_year', 'total_savings_per_year', 'rebates',
       'net_replacement_cost', 'payback'], axis=1)

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
sns.boxplot(x=new_dataframe['total_savings_per_year'])
# Out:
# <AxesSubplot:xlabel='payback'>

# %%
sns.boxplot(x=new_dataframe['rebates'])
# Out:
# <AxesSubplot:xlabel='rebates'>

# %%
sns.boxplot(x=new_dataframe['ROI'])
# Out:
# <AxesSubplot:xlabel='ROI'>

# %%
sns.boxplot(x=new_dataframe['payback'])
# Out:
# <AxesSubplot:xlabel='payback'>

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(new_dataframe['total_existing_quantity'],new_dataframe['ROI'])
ax.set_xlabel('total_existing_quantity')
ax.set_ylabel('ROI')
plt.show()

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(new_dataframe))
print(z)
# Out:
# [[           nan 6.22768751e-01 7.84946784e-02 ... 1.37186512e-02
#   5.21633273e-16 1.36830222e-02]
#  [           nan 7.77469996e-01 7.87580603e-02 ... 1.37182735e-02
#   1.46705745e+00 1.35965166e-02]
#  [           nan 7.77469996e-01 7.87580603e-02 ... 1.36755782e-02
#   5.21633273e-16 1.36830222e-02]
#  ...
#  [           nan 6.22768751e-01 7.87259405e-02 ... 1.37186581e-02
#   1.66674178e+00 1.36728971e-02]
#  [           nan 7.77469996e-01 7.87580603e-02 ... 1.37020390e-02
#   6.85939334e-01 1.36658906e-02]
#  [           nan 7.77469996e-01 7.87580603e-02 ... 1.37175466e-02
#   3.10806294e+00 1.36799077e-02]]
# C:\Users\pankt\anaconda3\lib\site-packages\scipy\stats\stats.py:2500: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
all0 = new_dataframe[(z < 3).all(axis=1)]
all0
# Out:
# Empty DataFrame
# Columns: [finance_discount_rate, area_count, area_count_sum, ave_annual_hours, monday_ave_daily_hours, tuesday_ave_daily_hours, wednesday_ave_daily_hours, thursday_ave_daily_hours, friday_ave_daily_hours, saturday_ave_daily_hours, sunday_ave_daily_hours, ave_weeks_per_year, max_kwh_cost, max_kwh_cost_simple, existing_lighting_count, total_watts_per_product, ave_lm70, total_existing_quantity, total_proposed_quantity, total_replacement_count, total_fixture_watts, total_fixture_watt_hours, total_fixture_life_years, total_item_watts, sol_total_existing_count, total_product_count, energy_savings_per_year, total_savings_per_year, rebates, net_replacement_cost, payback, ROI]
# Index: []
#
# [0 rows x 32 columns]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([  11,   20,   20, ..., 5403, 5413, 5424], dtype=int64), array([30,  1, 14, ...,  9,  9, 30], dtype=int64))

# %%
Q1 = new_dataframe.quantile(0.25)
Q3 = new_dataframe.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# finance_discount_rate        0.000000e+00
# area_count                   6.000000e+00
# area_count_sum               4.560000e+02
# ave_annual_hours             1.328000e+03
# monday_ave_daily_hours       0.000000e+00
# tuesday_ave_daily_hours      0.000000e+00
# wednesday_ave_daily_hours    0.000000e+00
# thursday_ave_daily_hours     0.000000e+00
# friday_ave_daily_hours       0.000000e+00
# saturday_ave_daily_hours     0.000000e+00
# sunday_ave_daily_hours       0.000000e+00
# ave_weeks_per_year           0.000000e+00
# max_kwh_cost                 5.000000e-02
# max_kwh_cost_simple          0.000000e+00
# existing_lighting_count      6.000000e+00
# total_watts_per_product      3.498230e+05
# ave_lm70                     7.611111e+03
# total_existing_quantity      9.480000e+02
# total_proposed_quantity      1.155000e+03
# total_replacement_count      5.470000e+02
# total_fixture_watts          8.802000e+02
# total_fixture_watt_hours     7.794180e+07
# total_fixture_life_years     4.236289e+02
# total_item_watts             1.991050e+04
# sol_total_existing_count     2.400000e+01
# total_product_count          3.000000e+01
# energy_savings_per_year      1.070527e+04
# total_savings_per_year       1.204483e+04
# rebates                      0.000000e+00
# net_replacement_cost         3.218280e+04
# payback                      1.670000e+00
# ROI                          3.968153e+01
# dtype: float64

# %%
new_out = new_dataframe[~((new_dataframe < (Q1 - 1.5 * IQR)) |(new_dataframe > (Q3 + 1.5 * IQR))).any(axis=1)]
new_out.shape
# Out:
# (1417, 32)

# %%
print(findata['payback'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['payback'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    5425.000000
# mean        2.837940
# std         1.702844
# min         0.000000
# 25%         1.720000
# 50%         2.837940
# 75%         3.390000
# max         9.990000
# Name: payback, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(findata['net_replacement_cost'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['net_replacement_cost'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    5.425000e+03
# mean     4.244899e+06
# std      3.094538e+08
# min      0.000000e+00
# 25%      3.758090e+03
# 50%      1.279451e+04
# 75%      3.594089e+04
# max      2.279273e+10
# Name: net_replacement_cost, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(findata['rebates'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['rebates'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    5.425000e+03
# mean     1.320295e+04
# std      3.296914e+04
# min     -4.300000e+03
# 25%      1.320295e+04
# 50%      1.320295e+04
# 75%      1.320295e+04
# max      1.681374e+06
# Name: rebates, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(findata['energy_savings_per_year'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['energy_savings_per_year'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    5.425000e+03
# mean     8.476328e+06
# std      6.232114e+08
# min     -4.640000e+03
# 25%      8.414515e+02
# 50%      3.621822e+03
# 75%      1.154672e+04
# max      4.590240e+10
# Name: energy_savings_per_year, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
list(set(findata.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('O'), dtype('int64'), dtype('bool')]

# %%
findata_ex = new_dataframe.select_dtypes(include = ['float64', 'int64'])
findata_ex.head()
# Out:
#    finance_discount_rate  area_count  area_count_sum  ave_annual_hours  \
# 0                      5           2              42       4880.000000
# 1                      5           1               1       1000.000000
# 2                      5           1               1       4249.181784
# 3                      5           5             936       3727.000000
# 4                      5           6             936       3727.000000
#
#    monday_ave_daily_hours  tuesday_ave_daily_hours  wednesday_ave_daily_hours  \
# 0                0.000000                 0.000000                   0.000000
# 1                0.000000                 0.000000                   0.000000
# 2                1.416117                 1.418917                   1.427601
# 3                0.000000                 0.000000                   0.000000
# 4                0.000000                 0.000000                   0.000000
#
#    thursday_ave_daily_hours  friday_ave_daily_hours  saturday_ave_daily_hours  \
# 0                  0.000000                0.000000                  0.000000
# 1                  0.000000                0.000000                  0.000000
# 2                  1.421139                1.421274                  0.911292
# 3                  0.000000                0.000000                  0.000000
# 4                  0.000000                0.000000                  0.000000
#
#    ...  total_fixture_life_years  total_item_watts  sol_total_existing_count  \
# 0  ...                  0.000000               0.0                         4
# 1  ...                 50.000000             130.0                         1
# 2  ...                  0.000000           12900.0                         2
# 3  ...                  0.000000               0.0                         6
# 4  ...                180.288462            1681.0                        12
#
#    total_product_count  energy_savings_per_year  total_savings_per_year  \
# 0                    4             0.000000e+00            0.000000e+00
# 1                    1             8.700000e+01            3.536667e+02
# 2                    2             0.000000e+00            0.000000e+00
# 3                    6             6.220000e-15            6.220000e-15
# 4                   10             9.665942e+02            1.044594e+03
#
#         rebates  net_replacement_cost  payback         ROI
# 0     18.000000                2.1300  2.83794    0.000000
# 1  13202.949855              119.0000  0.34000  297.198880
# 2  13202.949855            13330.0000  2.83794    0.000000
# 3  13202.949855                0.0000  2.83794   34.785931
# 4  13202.949855             8489.2094  2.83794   12.304965
#
# [5 rows x 32 columns]

# %%
findata_ex.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'finance_discount_rate'}>,
#         <AxesSubplot:title={'center':'area_count'}>,
#         <AxesSubplot:title={'center':'area_count_sum'}>,
#         <AxesSubplot:title={'center':'ave_annual_hours'}>,
#         <AxesSubplot:title={'center':'monday_ave_daily_hours'}>,
#         <AxesSubplot:title={'center':'tuesday_ave_daily_hours'}>],
#        [<AxesSubplot:title={'center':'wednesday_ave_daily_hours'}>,
#         <AxesSubplot:title={'center':'thursday_ave_daily_hours'}>,
#         <AxesSubplot:title={'center':'friday_ave_daily_hours'}>,
#         <AxesSubplot:title={'center':'saturday_ave_daily_hours'}>,
#         <AxesSubplot:title={'center':'sunday_ave_daily_hours'}>,
#         <AxesSubplot:title={'center':'ave_weeks_per_year'}>],
#        [<AxesSubplot:title={'center':'max_kwh_cost'}>,
#         <AxesSubplot:title={'center':'max_kwh_cost_simple'}>,
#         <AxesSubplot:title={'center':'existing_lighting_count'}>,
#         <AxesSubplot:title={'center':'total_watts_per_product'}>,
#         <AxesSubplot:title={'center':'ave_lm70'}>,
#         <AxesSubplot:title={'center':'total_existing_quantity'}>],
#        [<AxesSubplot:title={'center':'total_proposed_quantity'}>,
#         <AxesSubplot:title={'center':'total_replacement_count'}>,
#         <AxesSubplot:title={'center':'total_fixture_watts'}>,
#         <AxesSubplot:title={'center':'total_fixture_watt_hours'}>,
#         <AxesSubplot:title={'center':'total_fixture_life_years'}>,
#         <AxesSubplot:title={'center':'total_item_watts'}>],
#        [<AxesSubplot:title={'center':'sol_total_existing_count'}>,
#         <AxesSubplot:title={'center':'total_product_count'}>,
#         <AxesSubplot:title={'center':'energy_savings_per_year'}>,
#         <AxesSubplot:title={'center':'total_savings_per_year'}>,
#         <AxesSubplot:title={'center':'rebates'}>,
#         <AxesSubplot:title={'center':'net_replacement_cost'}>],
#        [<AxesSubplot:title={'center':'payback'}>,
#         <AxesSubplot:title={'center':'ROI'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
findata_ex_corr = findata_ex.corr()['ROI'][:-1] # -1 because the latest row is SalePrice
golden_features_list = findata_ex_corr[abs(findata_ex_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with ROI:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 0 strongly correlated values with ROI:
# Series([], Name: ROI, dtype: float64)

# %%
findata_ex_corr = findata_ex.corr()['payback'][:-1] # -1 because the latest row is SalePrice
golden_features_list = findata_ex_corr[abs(findata_ex_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with payback:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 1 strongly correlated values with payback:
# payback    1.0
# Name: payback, dtype: float64

# %%
for i in range(0, len(findata_ex.columns), 5):
    sns.pairplot(data=findata_ex,
                x_vars=findata_ex.columns[i:i+5],
                y_vars=findata_ex['ROI'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-317e2af89333> in <module>
#       1 for i in range(0, len(findata_ex.columns), 5):
# ----> 2     sns.pairplot(data=findata_ex,
#       3                 x_vars=findata_ex.columns[i:i+5],
#       4                 y_vars=findata_ex['ROI'])
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1923     # Set up the PairGrid
#    1924     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1925     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1926                     hue_order=hue_order, palette=palette, corner=corner,
#    1927                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1174         figsize = len(x_vars) * height * aspect, len(y_vars) * height
#    1175
# -> 1176         fig, axes = plt.subplots(len(y_vars), len(x_vars),
#    1177                                  figsize=figsize,
#    1178                                  sharex="col", sharey="row",
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1286     """
#    1287     fig = figure(**fig_kw)
# -> 1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1290                        gridspec_kw=gridspec_kw)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1520         if gridspec_kw is None:
#    1521             gridspec_kw = {}
# -> 1522         return (self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#    1523                 .subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#    1524                           subplot_kw=subplot_kw))
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     334                 subplot_kw["sharex"] = shared_with[sharex]
#     335                 subplot_kw["sharey"] = shared_with[sharey]
# --> 336                 axarr[row, col] = figure.add_subplot(
#     337                     self[row, col], **subplot_kw)
#     338
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
# -> 1404         return self._add_axes_internal(key, ax)
#    1405
#    1406     def _add_axes_internal(self, key, ax):
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in _add_axes_internal(self, key, ax)
#    1407         """Private helper for `add_axes` and `add_subplot`."""
#    1408         self._axstack.add(key, ax)
# -> 1409         self.sca(ax)
#    1410         ax._remove_method = self.delaxes
#    1411         self.stale = True
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in sca(self, a)
#    2067     def sca(self, a):
#    2068         """Set the current axes to be *a* and return *a*."""
# -> 2069         self._axstack.bubble(a)
#    2070         self._axobservers.process("_axes_change_event", self)
#    2071         return a
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in bubble(self, a)
#     102         stack, to the top.
#     103         """
# --> 104         return super().bubble(self._entry_from_axes(a))
#     105
#     106     def add(self, key, a):
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in bubble(self, o)
#     626                 top_elements.append(elem)
#     627             else:
# --> 628                 self.push(elem)
#     629         for _ in top_elements:
#     630             self.push(o)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in push(self, o)
#     585         """
#     586         self._elements = self._elements[:self._pos + 1] + [o]
# --> 587         self._pos = len(self._elements) - 1
#     588         return self()
#     589
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001BE5A26E940> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     178     if _is_transparent(fig.get_facecolor()):
#     179         # the background is transparent
# --> 180         ticksLight = _is_light([label.get_color()
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             tick.gridline.set_visible(self._gridOnMajor)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2301         else:
#    2302             tick_kw = self._minor_tick_kw
# -> 2303         return YTick(self.axes, 0, major=major, **tick_kw)
#    2304
#    2305     def set_label_position(self, position):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     490         super().__init__(*args, **kwargs)
#     491         # x in axes coords, y in data coords
# --> 492         self.tick1line.set(
#     493             xdata=[0], ydata=[0],
#     494             transform=self.axes.get_yaxis_transform(which="tick1"),
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1111         if move_color_to_start:
#    1112             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1113         return self.update(kwargs)
#    1114
#    1115     def findobj(self, match=None, include_self=True):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in set_marker(self, marker)
#    1155             arguments.
#    1156         """
# -> 1157         self._marker.set_marker(marker)
#    1158         self.stale = True
#    1159
#
# ~\anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     311         if not isinstance(marker, MarkerStyle):
#     312             self._marker = marker
# --> 313             self._recache()
#     314
#     315     def get_path(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     239         self._capstyle = 'butt'
#     240         self._filled = True
# --> 241         self._marker_function()
#     242
#     243     def __bool__(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickleft(self)
#     732
#     733     def _set_tickleft(self):
# --> 734         self._transform = Affine2D().scale(-1.0, 1.0)
#     735         self._snap_threshold = 1.0
#     736         self._filled = False
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1843         if matrix is None:
#    1844             # A bit faster than np.identity(3).
# -> 1845             matrix = IdentityTransform._mtx.copy()
#    1846         self._mtx = matrix.copy()
#    1847         self._invalid = 0
#
# KeyboardInterrupt:

# %%
import operator

individual_features_df = []
for i in range(0, len(findata_ex.columns) - 1): # -1 because the last column is ROI
    tmpDf = findata_ex[[findata_ex.columns[i], 'ROI']]
    tmpDf = tmpDf[tmpDf[findata_ex.columns[i]] != 0]
    individual_features_df.append(tmpDf)

all_correlations = {feature.columns[0]: feature.corr()['ROI'][0] for feature in individual_features_df}
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))

# %%
plt.plot(findata["project_id"]) 
plt.title("Project_id")
plt.show()

plt.plot(findata["option_id"]) 
plt.title("Option_id")
plt.show()

plt.plot(findata["option_calculation_id"]) 
plt.title("Option_calculation_id")
plt.show()

plt.plot(findata["company_id"]) 
plt.title("Company_id")
plt.show()

plt.plot(findata["facility_type_id"]) 
plt.title("Facility_type_id")
plt.show()

plt.plot(findata["industry_type_id"]) 
plt.title("Industry_type_id")
plt.show()

plt.plot(findata["tax_rate_source"])
plt.title("Tax_rate_source")
plt.show()

plt.plot(findata["finance_discount_rate"]) 
plt.title("Finance_discount_rate")
plt.show()

plt.plot(findata["area_count"]) 
plt.title("Area_count")
plt.show()

plt.plot(findata["area_count_sum"])
plt.title("Area_count_sum")
plt.show()

plt.plot(findata["ave_annual_hours"])
plt.title("Ave_annual_hours")
plt.show()

plt.plot(findata["monday_ave_daily_hours"])
plt.title("Monday_ave_daily_hours")
plt.show()

plt.plot(findata["tuesday_ave_daily_hours"])
plt.title("Tuesday_ave_daily_hours")
plt.show()

plt.plot(findata["wednesday_ave_daily_hours"])
plt.title("Wednesday_ave_daily_hours")
plt.show()

plt.plot(findata["thursday_ave_daily_hours"])
plt.title("Thursday_ave_daily_hours")
plt.show()

plt.plot(findata["friday_ave_daily_hours"])
plt.title("Friday_ave_daily_hours")
plt.show()

plt.plot(findata["saturday_ave_daily_hours"])
plt.title("Saturday_ave_daily_hours")
plt.show()

plt.plot(findata["sunday_ave_daily_hours"])
plt.title("Sunday_ave_daily_hours")
plt.show()

plt.plot(findata["hour_type"])
plt.title("Hour_type")
plt.show()

plt.plot(findata["max_kwh_cost"])
plt.title("Max_kwh_cost")
plt.show()

plt.plot(findata["max_kwh_cost_simple"])
plt.title("Max_kwh_cost_simple")
plt.show()

plt.plot(findata["existing_lighting_count"])
plt.title("Existing_lighting_count")
plt.show()

plt.plot(findata["total_watts_per_product"])
plt.title("Total_watts_per_product")
plt.show()

plt.plot(findata["ave_lm70"])
plt.title("Ave_lm70")
plt.show()

plt.plot(findata["total_solution_count"])
plt.title("total_solution_count")
plt.show()

plt.plot(findata["total_existing_quantity"])
plt.title("Total_existing_quantity")
plt.show()

plt.plot(findata["total_proposed_quantity"])
plt.title("Total_proposed_quantity")
plt.show()

plt.plot(findata["total_replacement_count"])
plt.title("Total_replacement_count")
plt.show()

plt.plot(findata["total_fixture_watts"])
plt.title("Total_fixture_watts")
plt.show()

plt.plot(findata["total_fixture_watt_hours"])
plt.title("Total_fixture_watt_hours")
plt.show()

plt.plot(findata["total_fixture_life_years"])
plt.title("Total_fixture_life_years")
plt.show()

plt.plot(findata["total_item_watts"])
plt.title("Total_item_watts")
plt.show()

plt.plot(findata["sol_total_existing_count"])
plt.title("Sol_total_existing_count")
plt.show()

plt.plot(findata["total_product_count"])
plt.title("Total_product_count")
plt.show()

plt.plot(findata["energy_savings_per_year"])
plt.title("Energy_savings_per_year")
plt.show()

plt.plot(findata["total_savings_per_year"])
plt.title("Total_savings_per_year")
plt.show()

plt.plot(findata["rebates"])
plt.title("Rebates")
plt.show()

plt.plot(findata["net_replacement_cost"])
plt.title("Net_replacement_cost")
plt.show()

plt.plot(findata["payback"])
plt.title("Payback")
plt.show()

plt.plot(findata["ROI"])
plt.title("ROI")
plt.show()

# %%
findata_1 = findata.filter(['project_id', 'option_id', 'option_calculation_id' , 'company_id', 'facility_type_id', 'industry_type_id'])
print(findata_1)
sns.pairplot(findata_1)
# Out:
#       project_id  option_id  option_calculation_id  company_id  \
# 0              3          8                   1235           5
# 1              8        290                   1398           7
# 2             11         92                   1221          15
# 3             15         21                   1782          19
# 4             15        928                   1781          19
# ...          ...        ...                    ...         ...
# 5420       12131      10277                  10273        1050
# 5421       12132      10278                  10274         155
# 5422       12137      10284                  10280         943
# 5423       12138      10286                  10282         118
# 5424       12143      10292                  10288         454
#
#       facility_type_id  industry_type_id
# 0                  0.0            2252.0
# 1                  0.0               0.0
# 2                 19.0               0.0
# 3                  0.0            2336.0
# 4                  0.0            2336.0
# ...                ...               ...
# 5420               0.0               0.0
# 5421              40.0               0.0
# 5422              62.0               0.0
# 5423              25.0               0.0
# 5424               0.0               0.0
#
# [5425 rows x 6 columns]

# %%
findata_2 = findata.filter(['tax_rate_source', 'finance_discount_rate', 'area_count', 'area_count_sum', 'ave_annual_hours'])
print(findata_2)
sns.pairplot(findata_2)
# Out:
#       tax_rate_source  finance_discount_rate  area_count  area_count_sum  \
# 0                 0.0                      5           2              42
# 1                 0.0                      5           1               1
# 2                 0.0                      5           1               1
# 3                 0.0                      5           5             936
# 4                 0.0                      5           6             936
# ...               ...                    ...         ...             ...
# 5420              2.0                      5           3              96
# 5421              2.0                      5           1              16
# 5422              2.0                      5           2               6
# 5423              2.0                      5           1               1
# 5424              2.0                      5           1               1
#
#       ave_annual_hours
# 0          4880.000000
# 1          1000.000000
# 2          4249.181784
# 3          3727.000000
# 4          3727.000000
# ...                ...
# 5420       4380.000000
# 5421       8760.000000
# 5422       4368.000000
# 5423       4249.181784
# 5424       5000.000000
#
# [5425 rows x 5 columns]

# %%
findata_3 = findata.filter(['monday_ave_daily_hours', 'tuesday_ave_daily_hours' , 'wednesday_ave_daily_hours' , 'thursday_ave_daily_hours',
'friday_ave_daily_hours', 'saturday_ave_daily_hours' , 'sunday_ave_daily_hours'])
print(findata_3)
sns.pairplot(findata_3)
# Out:
#       monday_ave_daily_hours  tuesday_ave_daily_hours  \
# 0                   0.000000                 0.000000
# 1                   0.000000                 0.000000
# 2                   1.416117                 1.418917
# 3                   0.000000                 0.000000
# 4                   0.000000                 0.000000
# ...                      ...                      ...
# 5420                9.500000                 9.500000
# 5421                5.000000                 5.000000
# 5422                0.000000                 0.000000
# 5423                9.000000                 9.000000
# 5424                0.000000                 0.000000
#
#       wednesday_ave_daily_hours  thursday_ave_daily_hours  \
# 0                      0.000000                  0.000000
# 1                      0.000000                  0.000000
# 2                      1.427601                  1.421139
# 3                      0.000000                  0.000000
# 4                      0.000000                  0.000000
# ...                         ...                       ...
# 5420                   9.500000                  9.500000
# 5421                   5.000000                  5.000000
# 5422                   0.000000                  0.000000
# 5423                   9.000000                  9.000000
# 5424                   0.000000                  0.000000
#
#       friday_ave_daily_hours  saturday_ave_daily_hours  sunday_ave_daily_hours
# 0                   0.000000                  0.000000                 0.00000
# 1                   0.000000                  0.000000                 0.00000
# 2                   1.421274                  0.911292                 0.52067
# 3                   0.000000                  0.000000                 0.00000
# 4                   0.000000                  0.000000                 0.00000
# ...                      ...                       ...                     ...
# 5420                9.500000                  0.000000                 0.00000
# 5421                6.000000                  6.000000                 0.00000
# 5422                0.000000                  0.000000                 0.00000
# 5423                9.000000                  9.000000                 0.00000
# 5424                0.000000                  0.000000                 0.00000
#
# [5425 rows x 7 columns]

# %%
findata_4 = findata.filter(['ave_weeks_per_year', 'hour_type',
       'max_kwh_cost', 'max_kwh_cost_simple', 'existing_lighting_count',
       'total_watts_per_product', 'ave_lm70'])
print(findata_4)
sns.pairplot(findata_4)
# Out:
#       ave_weeks_per_year  hour_type  max_kwh_cost  max_kwh_cost_simple  \
# 0               0.000000        1.0      6.554901             0.155228
# 1               0.000000        1.0      0.100000             0.155228
# 2               6.101727        0.0      6.554901             0.155228
# 3               0.000000        1.0      0.100000             0.155228
# 4               0.000000        1.0      0.100000             0.155228
# ...                  ...        ...           ...                  ...
# 5420           52.000000        2.0      6.554901             0.085000
# 5421           26.000000        2.0      0.100000             0.155228
# 5422            0.000000        1.0      0.120000             0.155228
# 5423           51.000000        2.0      0.100000             0.155228
# 5424            0.000000        1.0      0.080000             0.155228
#
#       existing_lighting_count  total_watts_per_product     ave_lm70
# 0                           2                   3276.0  13333.33333
# 1                           1                    100.0   1000.00000
# 2                           1                   1080.0  10000.00000
# 3                           5                 662760.0  22538.46154
# 4                           6                 795312.0  22538.46154
# ...                       ...                      ...          ...
# 5420                        3                 100368.0  17500.00000
# 5421                        1                    680.0  20000.00000
# 5422                        2                    360.0  10500.00000
# 5423                        1                    464.0  10000.00000
# 5424                        1                     82.0  10000.00000
#
# [5425 rows x 7 columns]

# %%
findata_5 = findata.filter(['total_solution_count',
       'total_existing_quantity', 'total_proposed_quantity',
       'total_replacement_count', 'total_fixture_watts',
       'total_fixture_watt_hours, , , 'rebates',
       'net_replacement_cost', 'payback', 'ROI'
print(findata_5)
sns.pairplot(findata_5)

# %%
findata_6 = findata.filter(['total_fixture_life_years',
       'total_item_watts', 'sol_total_existing_count', 'total_product_count',
       'energy_savings_per_year', 'total_savings_per_year'])
print(findata_6)
sns.pairplot(findata_6)

# %%
findata_7 = findata.filter(['rebates',
       'net_replacement_cost', 'payback', 'ROI'])
print(findata_7)
sns.pairplot(findata_7)
