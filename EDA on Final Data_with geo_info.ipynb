# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\pankt\\Omdena Retrolux\\Final Data_with geo_info.csv')

# %%
data.shape
# Out:
# (3856, 49)

# %%
data.head()
# Out:
#    Unnamed: 0  project_id  option_id  option_calculation_id  company_id  \
# 0           0          11         92                   1221          15
# 1           1          11         92                   1221          15
# 2           2          11         92                   1221          15
# 3           3          15        928                   1781          19
# 4           4          15        928                   1781          19
#
#                                     projects_name  facility_type_id  \
# 0                                Golden Spoon_257              19.0
# 1                                Golden Spoon_257              19.0
# 2                                Golden Spoon_257              19.0
# 3  Demo Project - updated and synced name - again               NaN
# 4  Demo Project - updated and synced name - again               NaN
#
#            facility_type  industry_type_id                          name  ...  \
# 0  Fast Food Restaurants               NaN   Anderson, Shields and Hyatt  ...
# 1  Fast Food Restaurants               NaN   Anderson, Shields and Hyatt  ...
# 2  Fast Food Restaurants               NaN   Anderson, Shields and Hyatt  ...
# 3                    NaN            2336.0  Blanda, Stiedemann and Kiehn  ...
# 4                    NaN            2336.0  Blanda, Stiedemann and Kiehn  ...
#
#          ROI addresses_id          addressable_type  address_type  \
# 0   0.000000           41                   Project             1
# 1   0.000000         1831                     Order             2
# 2   0.000000         5713  ProjectFinancingEstimate             1
# 3  12.304965           38                   Company             1
# 4  12.304965         1870                     Order             2
#
#                    address         city  state  zip_code   latitude  \
# 0              1515 US-169   Smithville     MO     64089  39.412870
# 1  1775 W State St PMB 125        Boise     ID     83702  43.624184
# 2           300 NW 16th St    Fruitland     ID     83619  44.025320
# 3       735 Southwest Blvd  Kansas City     KS     66103  39.063046
# 4  1775 W State St PMB 125        Boise     ID     83702  43.624184
#
#     longitude
# 0  -94.583700
# 1 -116.212220
# 2 -116.916565
# 3  -94.618360
# 4 -116.212220
#
# [5 rows x 49 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3856 entries, 0 to 3855
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                3856 non-null   int64
#  1   project_id                3856 non-null   int64
#  2   option_id                 3856 non-null   int64
#  3   option_calculation_id     3856 non-null   int64
#  4   company_id                3856 non-null   int64
#  5   projects_name             3856 non-null   object
#  6   facility_type_id          2316 non-null   float64
#  7   facility_type             2316 non-null   object
#  8   industry_type_id          2048 non-null   float64
#  9   name                      3856 non-null   object
#  10  started_at                3856 non-null   object
#  11  finished_at               3856 non-null   object
#  12  tax_rate_source           3825 non-null   float64
#  13  finance_discount_rate     3856 non-null   int64
#  14  tax_exempt                3856 non-null   bool
#  15  active                    3856 non-null   bool
#  16  area_count                3856 non-null   int64
#  17  area_count_sum            3856 non-null   int64
#  18  ave_annual_hours          3736 non-null   float64
#  19  max_kwh_cost              3654 non-null   float64
#  20  max_kwh_cost_simple       60 non-null     float64
#  21  existing_lighting_count   3856 non-null   int64
#  22  total_watts_per_product   3856 non-null   float64
#  23  ave_lm70                  3856 non-null   float64
#  24  total_solution_count      3856 non-null   int64
#  25  total_existing_quantity   3856 non-null   int64
#  26  total_proposed_quantity   3856 non-null   int64
#  27  total_replacement_count   3617 non-null   float64
#  28  total_fixture_watts       3617 non-null   float64
#  29  total_fixture_watt_hours  3617 non-null   float64
#  30  total_fixture_life_years  3617 non-null   float64
#  31  total_item_watts          3617 non-null   float64
#  32  sol_total_existing_count  3856 non-null   int64
#  33  total_product_count       3856 non-null   int64
#  34  energy_savings_per_year   3856 non-null   float64
#  35  total_savings_per_year    3856 non-null   float64
#  36  rebates                   615 non-null    float64
#  37  net_replacement_cost      3856 non-null   float64
#  38  payback                   3037 non-null   float64
#  39  ROI                       3856 non-null   float64
#  40  addresses_id              3856 non-null   int64
#  41  addressable_type          3856 non-null   object
#  42  address_type              3856 non-null   int64
#  43  address                   3856 non-null   object
#  44  city                      3856 non-null   object
#  45  state                     3845 non-null   object
#  46  zip_code                  3856 non-null   int64
#  47  latitude                  3856 non-null   float64
#  48  longitude                 3856 non-null   float64
# dtypes: bool(2), float64(21), int64(17), object(9)
# memory usage: 1.4+ MB

# %%
data['ROI'].describe()
# Out:
# count    3856.000000
# mean       39.226946
# std        29.113224
# min         0.000000
# 25%        18.413258
# 50%        33.132743
# 75%        54.540414
# max       119.575482
# Name: ROI, dtype: float64

# %%
findata=data.drop(data.iloc[:, [0]], axis=1)
findata.shape
# Out:
# (3856, 48)

# %%
findata.columns
# Out:
# Index(['project_id', 'option_id', 'option_calculation_id', 'company_id',
#        'projects_name', 'facility_type_id', 'facility_type',
#        'industry_type_id', 'name', 'started_at', 'finished_at',
#        'tax_rate_source', 'finance_discount_rate', 'tax_exempt', 'active',
#        'area_count', 'area_count_sum', 'ave_annual_hours', 'max_kwh_cost',
#        'max_kwh_cost_simple', 'existing_lighting_count',
#        'total_watts_per_product', 'ave_lm70', 'total_solution_count',
#        'total_existing_quantity', 'total_proposed_quantity',
#        'total_replacement_count', 'total_fixture_watts',
#        'total_fixture_watt_hours', 'total_fixture_life_years',
#        'total_item_watts', 'sol_total_existing_count', 'total_product_count',
#        'energy_savings_per_year', 'total_savings_per_year', 'rebates',
#        'net_replacement_cost', 'payback', 'ROI', 'addresses_id',
#        'addressable_type', 'address_type', 'address', 'city', 'state',
#        'zip_code', 'latitude', 'longitude'],
#       dtype='object')

# %%
descd = findata.describe()

for i in range(41):
    print(descd.iloc[:,[i]])
    print("\n")
# Out:
#          project_id
# count   3856.000000
# mean    4633.388485
# std     3660.485923
# min       11.000000
# 25%      899.000000
# 50%     4608.000000
# 75%     7226.250000
# max    12138.000000
#
#
#           option_id
# count   3856.000000
# mean    4458.063537
# std     3242.851560
# min        3.000000
# 25%     1032.000000
# 50%     4538.500000
# 75%     7206.250000
# max    10286.000000
#
#
#        option_calculation_id
# count            3856.000000
# mean             4522.671940
# std              3146.243402
# min                 5.000000
# 25%              1435.000000
# 50%              4503.500000
# 75%              7177.250000
# max             10282.000000
#
#
#         company_id
# count  3856.000000
# mean    328.429720
# std     224.145018
# min       7.000000
# 25%     128.000000
# 50%     321.000000
# 75%     447.000000
# max    1050.000000
#
#
#        facility_type_id
# count       2316.000000
# mean          34.983592
# std           18.857031
# min            1.000000
# 25%           22.000000
# 50%           37.000000
# 75%           52.000000
# max           65.000000
#
#
#        industry_type_id
# count       2048.000000
# mean        2263.455566
# std           39.248248
# min         2214.000000
# 25%         2239.000000
# 50%         2251.000000
# 75%         2254.000000
# max         2357.000000
#
#
#        tax_rate_source
# count      3825.000000
# mean          1.998431
# std           0.055997
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           2.000000
# max           2.000000
#
#
#        finance_discount_rate
# count                 3856.0
# mean                     5.0
# std                      0.0
# min                      5.0
# 25%                      5.0
# 50%                      5.0
# 75%                      5.0
# max                      5.0
#
#
#         area_count
# count  3856.000000
# mean      5.727438
# std       6.323090
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       8.000000
# max      90.000000
#
#
#        area_count_sum
# count    3.856000e+03
# mean     1.617471e+04
# std      1.845721e+05
# min      1.000000e+00
# 25%      8.000000e+00
# 50%      6.900000e+01
# 75%      4.290000e+02
# max      7.680576e+06
#
#
#        ave_annual_hours
# count       3736.000000
# mean        4101.354052
# std         1570.233603
# min            1.000000
# 25%         3100.000000
# 50%         3940.000000
# 75%         4649.333333
# max        13383.333330
#
#
#        max_kwh_cost
# count   3654.000000
# mean      11.258445
# std      280.953510
# min        0.000000
# 25%        0.087000
# 50%        0.100000
# 75%        0.120000
# max     8760.000000
#
#
#        max_kwh_cost_simple
# count            60.000000
# mean              0.181430
# std               0.283517
# min               0.045000
# 25%               0.067500
# 50%               0.085000
# 75%               0.086250
# max               0.961000
#
#
#        existing_lighting_count
# count              3856.000000
# mean                  5.727438
# std                   6.323090
# min                   1.000000
# 25%                   2.000000
# 50%                   4.000000
# 75%                   8.000000
# max                  90.000000
#
#
#        total_watts_per_product
# count             3.856000e+03
# mean              1.019792e+08
# std               1.503089e+09
# min               0.000000e+00
# 25%               3.090000e+03
# 50%               3.278400e+04
# 75%               3.443685e+05
# max               6.705777e+10
#
#
#             ave_lm70
# count    3856.000000
# mean    16799.921825
# std      6822.798493
# min         0.000000
# 25%     12500.000000
# 50%     16666.666670
# 75%     20000.000000
# max    156000.000000
#
#
#        total_solution_count
# count           3856.000000
# mean               5.727438
# std                6.323090
# min                1.000000
# 25%                2.000000
# 50%                4.000000
# 75%                8.000000
# max               90.000000
#
#
#        total_existing_quantity
# count             3.856000e+03
# mean              5.193999e+03
# std               5.558820e+04
# min               0.000000e+00
# 25%               3.900000e+01
# 50%               1.600000e+02
# 75%               9.060000e+02
# max               2.375117e+06
#
#
#        total_proposed_quantity
# count             3.856000e+03
# mean              8.037222e+03
# std               1.164526e+05
# min               0.000000e+00
# 25%               3.900000e+01
# 50%               1.820000e+02
# 75%               1.197250e+03
# max               6.628561e+06
#
#
#        total_replacement_count
# count             3.617000e+03
# mean              1.425378e+03
# std               2.885934e+04
# min               0.000000e+00
# 25%               4.500000e+01
# 50%               1.350000e+02
# 75%               4.620000e+02
# max               1.000050e+06
#
#
#        total_fixture_watts
# count         3.617000e+03
# mean          3.163012e+04
# std           1.065164e+06
# min           0.000000e+00
# 25%           1.190000e+02
# 50%           2.980000e+02
# 75%           6.980000e+02
# max           3.699639e+07
#
#
#        total_fixture_watt_hours
# count              3.617000e+03
# mean               1.006514e+08
# std                7.212447e+08
# min                0.000000e+00
# 25%                6.289920e+06
# 50%                2.031376e+07
# 75%                6.127380e+07
# max                2.003750e+10
#
#
#        total_fixture_life_years
# count              3.617000e+03
# mean               3.764297e+03
# std                7.635033e+04
# min                0.000000e+00
# 25%                3.205128e+01
# 50%                9.384384e+01
# 75%                2.847064e+02
# max                2.118326e+06
#
#
#        total_item_watts
# count      3.617000e+03
# mean       3.000842e+05
# std        9.587426e+06
# min        0.000000e+00
# 25%        1.996000e+03
# 50%        5.784000e+03
# 75%        1.662000e+04
# max        3.329675e+08
#
#
#        sol_total_existing_count
# count               3856.000000
# mean                  40.795124
# std                  177.523067
# min                    1.000000
# 25%                    3.000000
# 50%                    8.000000
# 75%                   23.000000
# max                 4402.000000
#
#
#        total_product_count
# count          3856.000000
# mean             50.037863
# std             214.893981
# min               0.000000
# 25%               3.000000
# 50%               9.000000
# 75%              30.000000
# max            4402.000000
#
#
#        energy_savings_per_year
# count             3.856000e+03
# mean              1.366057e+04
# std               8.623942e+04
# min              -4.640000e+03
# 25%               9.611430e+02
# 50%               3.459988e+03
# 75%               1.073365e+04
# max               2.809498e+06
#
#
#        total_savings_per_year
# count            3.856000e+03
# mean             1.511656e+04
# std              8.711594e+04
# min              0.000000e+00
# 25%              1.055153e+03
# 50%              3.907266e+03
# 75%              1.208684e+04
# max              2.809498e+06
#
#
#              rebates
# count     615.000000
# mean     8569.603293
# std     14064.567454
# min       -45.000000
# 25%      1255.000000
# 50%      3300.000000
# 75%      9504.775000
# max    133341.520000
#
#
#        net_replacement_cost
# count          3.856000e+03
# mean           5.423254e+04
# std            4.053333e+05
# min            0.000000e+00
# 25%            4.282092e+03
# 50%            1.345447e+04
# 75%            3.800938e+04
# max            1.040160e+07
#
#
#            payback
# count  3037.000000
# mean      3.039865
# std       1.803508
# min       0.000000
# 25%       1.680000
# 50%       2.570000
# 75%       3.930000
# max       9.630000
#
#
#                ROI
# count  3856.000000
# mean     39.226946
# std      29.113224
# min       0.000000
# 25%      18.413258
# 50%      33.132743
# 75%      54.540414
# max     119.575482
#
#
#        addresses_id
# count   3856.000000
# mean   16036.328838
# std     8977.339062
# min       38.000000
# 25%     7912.750000
# 50%    15870.500000
# 75%    22467.000000
# max    34762.000000
#
#
#        address_type
# count   3856.000000
# mean       1.581432
# std        1.393000
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        5.000000
#
#
#            zip_code
# count   3856.000000
# mean   52831.196836
# std    25539.029867
# min    10010.000000
# 25%    32504.000000
# 50%    49441.000000
# 75%    78228.000000
# max    99999.000000
#
#
#           latitude
# count  3856.000000
# mean     37.435453
# std       5.235175
# min      18.217648
# 25%      33.434317
# 50%      39.042632
# 75%      41.220250
# max      60.512640
#
#
#          longitude
# count  3856.000000
# mean    -92.731167
# std      13.889047
# min    -150.906160
# 25%     -98.568351
# 50%     -87.719075
# 75%     -81.461935
# max     -66.410800
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-a9d89f9d67b3> in <module>
#       2
#       3 for i in range(41):
# ----> 4     print(descd.iloc[:,[i]])
#       5     print("\n")
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#     704                 raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1365             # check that the key does not exceed the maximum size of the index
#    1366             if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 1367                 raise IndexError("positional indexers are out-of-bounds")
#    1368         else:
#    1369             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %%
findata.isnull().any()

# %%
findata.corr()

# %%
new_dataframe = findata.filter(['finance_discount_rate', 
       'area_count', 'area_count_sum', 'ave_annual_hours',
       'monday_ave_daily_hours', 'tuesday_ave_daily_hours',
       'wednesday_ave_daily_hours', 'thursday_ave_daily_hours',
       'friday_ave_daily_hours', 'saturday_ave_daily_hours',
       'sunday_ave_daily_hours', 'ave_weeks_per_year', 
       'max_kwh_cost', 'max_kwh_cost_simple', 'existing_lighting_count',
       'total_watts_per_product', 'ave_lm70',
       'total_existing_quantity', 'total_proposed_quantity',
       'total_replacement_count', 'total_fixture_watts',
       'total_fixture_watt_hours', 'total_fixture_life_years',
       'total_item_watts', 'sol_total_existing_count', 'total_product_count',
       'energy_savings_per_year', 'total_savings_per_year', 'rebates',
       'net_replacement_cost', 'payback', 'ROI'], axis=1)

new_dataframe_1 = new_dataframe.filter(['finance_discount_rate', 
       'area_count', 'area_count_sum', 'ave_annual_hours',
       'monday_ave_daily_hours', 'tuesday_ave_daily_hours',
       'wednesday_ave_daily_hours', 'thursday_ave_daily_hours',
       'friday_ave_daily_hours', 'saturday_ave_daily_hours',
       'sunday_ave_daily_hours', 'ave_weeks_per_year', 
       'max_kwh_cost', 'max_kwh_cost_simple', 'existing_lighting_count',
       'total_watts_per_product', 'ave_lm70',
       'total_existing_quantity', 'total_proposed_quantity',
       'total_replacement_count', 'total_fixture_watts',
       'total_fixture_watt_hours', 'total_fixture_life_years',
       'total_item_watts', 'sol_total_existing_count', 'total_product_count',
       'energy_savings_per_year', 'total_savings_per_year', 'rebates',
       'net_replacement_cost', 'payback'], axis=1)
import seaborn as sns
sns.boxplot(x=new_dataframe['total_savings_per_year'])
# Out:
# <AxesSubplot:xlabel='total_savings_per_year'>

# %%
sns.boxplot(x=new_dataframe['rebates'])
# Out:
# <AxesSubplot:xlabel='rebates'>

# %%
sns.boxplot(x=new_dataframe['ROI'])
# Out:
# <AxesSubplot:xlabel='ROI'>

# %%
sns.boxplot(x=new_dataframe['payback'])
# Out:
# <AxesSubplot:xlabel='payback'>

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(new_dataframe['total_existing_quantity'],new_dataframe['ROI'])
ax.set_xlabel('total_existing_quantity')
ax.set_ylabel('ROI')
plt.show()

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(new_dataframe))
print(z)
# Out:
# [[       nan 0.74774377 0.08763951 ... 0.10092395        nan 1.34756749]
#  [       nan 0.74774377 0.08763951 ... 0.10092395        nan 1.34756749]
#  [       nan 0.74774377 0.08763951 ... 0.10092395        nan 1.34756749]
#  ...
#  [       nan 0.58957273 0.08686464 ... 0.13381473        nan 2.76022185]
#  [       nan 0.43140168 0.08751488 ... 0.13381473        nan 2.76022185]
#  [       nan 0.58957273 0.08761241 ... 0.13381473        nan 2.76022185]]
# C:\Users\pankt\anaconda3\lib\site-packages\scipy\stats\stats.py:2500: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
all0 = new_dataframe[(z < 3).all(axis=1)]
all0
# Out:
# Empty DataFrame
# Columns: [finance_discount_rate, area_count, area_count_sum, ave_annual_hours, max_kwh_cost, max_kwh_cost_simple, existing_lighting_count, total_watts_per_product, ave_lm70, total_existing_quantity, total_proposed_quantity, total_replacement_count, total_fixture_watts, total_fixture_watt_hours, total_fixture_life_years, total_item_watts, sol_total_existing_count, total_product_count, energy_savings_per_year, total_savings_per_year, rebates, net_replacement_cost, payback, ROI]
# Index: []
#
# [0 rows x 24 columns]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([  49,   49,  111,  111,  111,  111,  112,  112,  112,  112,  123,
#         123,  123,  123,  123,  124,  124,  124,  124,  124,  125,  125,
#         125,  125,  125,  327,  327,  328,  328,  329,  329,  465,  465,
#         466,  466,  498,  499,  500,  501,  502,  547,  547,  548,  548,
#         549,  549,  738,  738,  738,  739,  739,  739,  740,  740,  740,
#         806,  806,  807,  807, 1267, 1267, 1268, 1268, 1299, 1299, 1299,
#        1299, 1300, 1300, 1300, 1300, 1301, 1301, 1301, 1301, 1402, 1402,
#        1402, 1402, 1402, 1402, 1402, 1402, 1430, 1430, 1431, 1431, 1434,
#        1434, 1435, 1435, 1439, 1486, 1486, 1486, 1587, 1587, 1587, 1700,
#        1723, 1742, 1742, 1742, 1742, 1760, 1794, 1794, 1795, 1795, 1822,
#        1822, 1824, 1824, 1825, 1825, 1836, 1836, 1837, 1837, 1838, 1838,
#        1906, 2050, 2050, 2051, 2051, 2052, 2052, 2119, 2119, 2123, 2151,
#        2151, 2216, 2217, 2219, 2219, 2220, 2220, 2221, 2221, 2221, 2247,
#        2248, 2275, 2276, 2279, 2326, 2342, 2342, 2343, 2343, 2344, 2344,
#        2427, 2433, 2433, 2433, 2435, 2435, 2435, 2457, 2457, 2467, 2499,
#        2499, 2499, 2499, 2499, 2499, 2562, 2800, 2800, 2802, 2810, 2853,
#        2854, 2855, 2856, 2857, 2858, 2859, 2894, 2933, 2933, 2958, 3070,
#        3081, 3087, 3112, 3113, 3114, 3114, 3115, 3115, 3125, 3125, 3126,
#        3126, 3128, 3128, 3128, 3129, 3129, 3129, 3136, 3137, 3223, 3223,
#        3293, 3373, 3373, 3385, 3385, 3386, 3386, 3386, 3389, 3389, 3447,
#        3460, 3460, 3526, 3527, 3536, 3537, 3538, 3539, 3544, 3544, 3544,
#        3544, 3545, 3545, 3545, 3545, 3546, 3546, 3546, 3546, 3547, 3547,
#        3547, 3547, 3548, 3548, 3548, 3548, 3549, 3549, 3549, 3549, 3550,
#        3550, 3550, 3550, 3551, 3551, 3551, 3551, 3552, 3552, 3552, 3552,
#        3553, 3553, 3553, 3553, 3554, 3554, 3554, 3554, 3555, 3555, 3555,
#        3555, 3556, 3556, 3556, 3556, 3557, 3557, 3557, 3557, 3558, 3558,
#        3558, 3558, 3559, 3559, 3559, 3559, 3560, 3560, 3560, 3560, 3561,
#        3561, 3561, 3561, 3562, 3562, 3562, 3562, 3563, 3563, 3563, 3563,
#        3564, 3564, 3564, 3564, 3565, 3565, 3565, 3565, 3591, 3600, 3600,
#        3723, 3723, 3723, 3723, 3765, 3765, 3766, 3766, 3792, 3793],
#       dtype=int64), array([ 1,  6, 16, 17, 18, 19, 16, 17, 18, 19,  9, 10, 18, 19, 21,  9, 10,
#        18, 19, 21,  9, 10, 18, 19, 21, 16, 17, 16, 17, 16, 17, 16, 17, 16,
#        17, 16, 16, 16, 16, 16, 16, 17, 16, 17, 16, 17, 18, 19, 21, 18, 19,
#        21, 18, 19, 21,  1,  6,  1,  6, 18, 19, 18, 19,  1,  6, 10, 17,  1,
#         6, 10, 17,  1,  6, 10, 17,  1,  2,  6,  7,  9, 10, 16, 17,  1,  6,
#         1,  6,  1,  6,  1,  6, 17,  9, 10, 17, 18, 19, 21,  8,  8,  1,  6,
#        16, 17,  8,  1,  6,  1,  6,  1,  6,  1,  6,  1,  6,  1,  6,  1,  6,
#         1,  6, 16,  9, 10,  9, 10,  9, 10,  1,  6,  8,  9, 16,  8, 21, 18,
#        19, 18, 19,  1,  6, 16,  8,  8,  8,  8,  8,  8,  1,  6,  1,  6,  1,
#         6,  8,  1,  6,  9,  1,  6,  9,  1,  6, 16,  1,  6,  9, 10, 16, 17,
#        21, 16, 17, 17,  8, 16, 16, 16, 16, 16, 16, 16, 17, 16, 17,  8,  8,
#         8,  8, 17, 17, 16, 17, 16, 17, 16, 17, 16, 17, 10, 16, 17, 10, 16,
#        17, 17, 17, 16, 17, 16, 16, 17, 16, 17,  9, 16, 17, 16, 17, 16, 16,
#        17,  8,  8,  8,  8,  8,  8,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,
#         6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,  6,
#         7,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,  6,  7,
#         1,  2,  6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  1,
#         2,  6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  1,  2,
#         6,  7,  1,  2,  6,  7,  1,  2,  6,  7,  8,  1,  6,  9, 10, 16, 17,
#         1,  6,  1,  6,  8,  8], dtype=int64))

# %%
Q1 = new_dataframe.quantile(0.25)
Q3 = new_dataframe.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# finance_discount_rate       0.000000e+00
# area_count                  6.000000e+00
# area_count_sum              4.210000e+02
# ave_annual_hours            1.549333e+03
# max_kwh_cost                3.300000e-02
# max_kwh_cost_simple         1.875000e-02
# existing_lighting_count     6.000000e+00
# total_watts_per_product     3.412785e+05
# ave_lm70                    7.500000e+03
# total_existing_quantity     8.670000e+02
# total_proposed_quantity     1.158250e+03
# total_replacement_count     4.170000e+02
# total_fixture_watts         5.790000e+02
# total_fixture_watt_hours    5.498388e+07
# total_fixture_life_years    2.526552e+02
# total_item_watts            1.462400e+04
# sol_total_existing_count    2.000000e+01
# total_product_count         2.700000e+01
# energy_savings_per_year     9.772502e+03
# total_savings_per_year      1.103169e+04
# rebates                     8.249775e+03
# net_replacement_cost        3.372729e+04
# payback                     2.250000e+00
# ROI                         3.612716e+01
# dtype: float64

# %%
new_out = new_dataframe[~((new_dataframe < (Q1 - 1.5 * IQR)) |(new_dataframe > (Q3 + 1.5 * IQR))).any(axis=1)]
new_out.shape
# Out:
# (1894, 24)

# %%
print(findata['payback'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['payback'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    3037.000000
# mean        3.039865
# std         1.803508
# min         0.000000
# 25%         1.680000
# 50%         2.570000
# 75%         3.930000
# max         9.630000
# Name: payback, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(findata['net_replacement_cost'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['net_replacement_cost'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    3.856000e+03
# mean     5.423254e+04
# std      4.053333e+05
# min      0.000000e+00
# 25%      4.282092e+03
# 50%      1.345447e+04
# 75%      3.800938e+04
# max      1.040160e+07
# Name: net_replacement_cost, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(findata['rebates'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['rebates'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count       615.000000
# mean       8569.603293
# std       14064.567454
# min         -45.000000
# 25%        1255.000000
# 50%        3300.000000
# 75%        9504.775000
# max      133341.520000
# Name: rebates, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(findata['energy_savings_per_year'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(findata['energy_savings_per_year'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    3.856000e+03
# mean     1.366057e+04
# std      8.623942e+04
# min     -4.640000e+03
# 25%      9.611430e+02
# 50%      3.459988e+03
# 75%      1.073365e+04
# max      2.809498e+06
# Name: energy_savings_per_year, dtype: float64
# C:\Users\pankt\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
list(set(findata.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('int64'), dtype('float64'), dtype('bool')]

# %%
findata_ex = new_dataframe.select_dtypes(include = ['float64', 'int64'])
findata_ex.head()
# Out:
#    finance_discount_rate  area_count  area_count_sum  ave_annual_hours  \
# 0                      5           1               1               NaN
# 1                      5           1               1               NaN
# 2                      5           1               1               NaN
# 3                      5           6             936            3727.0
# 4                      5           6             936            3727.0
#
#    max_kwh_cost  max_kwh_cost_simple  existing_lighting_count  \
# 0           NaN                  NaN                        1
# 1           NaN                  NaN                        1
# 2           NaN                  NaN                        1
# 3           0.1                  NaN                        6
# 4           0.1                  NaN                        6
#
#    total_watts_per_product     ave_lm70  total_existing_quantity  ...  \
# 0                   1080.0  10000.00000                       86  ...
# 1                   1080.0  10000.00000                       86  ...
# 2                   1080.0  10000.00000                       86  ...
# 3                 795312.0  22538.46154                      138  ...
# 4                 795312.0  22538.46154                      138  ...
#
#    total_fixture_life_years  total_item_watts  sol_total_existing_count  \
# 0                  0.000000           12900.0                         2
# 1                  0.000000           12900.0                         2
# 2                  0.000000           12900.0                         2
# 3                180.288462            1681.0                        12
# 4                180.288462            1681.0                        12
#
#    total_product_count  energy_savings_per_year  total_savings_per_year  \
# 0                    2                  0.00000                 0.00000
# 1                    2                  0.00000                 0.00000
# 2                    2                  0.00000                 0.00000
# 3                   10                966.59424              1044.59424
# 4                   10                966.59424              1044.59424
#
#    rebates  net_replacement_cost  payback        ROI
# 0      NaN            13330.0000      NaN   0.000000
# 1      NaN            13330.0000      NaN   0.000000
# 2      NaN            13330.0000      NaN   0.000000
# 3      NaN             8489.2094      NaN  12.304965
# 4      NaN             8489.2094      NaN  12.304965
#
# [5 rows x 24 columns]

# %%
findata_ex.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'finance_discount_rate'}>,
#         <AxesSubplot:title={'center':'area_count'}>,
#         <AxesSubplot:title={'center':'area_count_sum'}>,
#         <AxesSubplot:title={'center':'ave_annual_hours'}>,
#         <AxesSubplot:title={'center':'max_kwh_cost'}>],
#        [<AxesSubplot:title={'center':'max_kwh_cost_simple'}>,
#         <AxesSubplot:title={'center':'existing_lighting_count'}>,
#         <AxesSubplot:title={'center':'total_watts_per_product'}>,
#         <AxesSubplot:title={'center':'ave_lm70'}>,
#         <AxesSubplot:title={'center':'total_existing_quantity'}>],
#        [<AxesSubplot:title={'center':'total_proposed_quantity'}>,
#         <AxesSubplot:title={'center':'total_replacement_count'}>,
#         <AxesSubplot:title={'center':'total_fixture_watts'}>,
#         <AxesSubplot:title={'center':'total_fixture_watt_hours'}>,
#         <AxesSubplot:title={'center':'total_fixture_life_years'}>],
#        [<AxesSubplot:title={'center':'total_item_watts'}>,
#         <AxesSubplot:title={'center':'sol_total_existing_count'}>,
#         <AxesSubplot:title={'center':'total_product_count'}>,
#         <AxesSubplot:title={'center':'energy_savings_per_year'}>,
#         <AxesSubplot:title={'center':'total_savings_per_year'}>],
#        [<AxesSubplot:title={'center':'rebates'}>,
#         <AxesSubplot:title={'center':'net_replacement_cost'}>,
#         <AxesSubplot:title={'center':'payback'}>,
#         <AxesSubplot:title={'center':'ROI'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
findata_ex_corr = findata_ex.corr()['ROI'][:-1] # -1 because the latest row is SalePrice
golden_features_list = findata_ex_corr[abs(findata_ex_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with ROI:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 1 strongly correlated values with ROI:
# payback   -0.822903
# Name: ROI, dtype: float64

# %%
findata_ex_corr = findata_ex.corr()['payback'][:-1] # -1 because the latest row is SalePrice
golden_features_list = findata_ex_corr[abs(findata_ex_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with payback:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 1 strongly correlated values with payback:
# payback    1.0
# Name: payback, dtype: float64

# %%
findata['facility_type']
# Out:
# 0              Fast Food Restaurants
# 1              Fast Food Restaurants
# 2              Fast Food Restaurants
# 3                                NaN
# 4                                NaN
#                     ...
# 3851                           Other
# 3852    Warehouse (Not Refrigerated)
# 3853               Commercial Condos
# 3854                          Retail
# 3855    Warehouse (Not Refrigerated)
# Name: facility_type, Length: 3856, dtype: object

# %%
plt.plot(findata["project_id"]) 
plt.title("Project_id")
plt.show()

plt.plot(findata["option_id"]) 
plt.title("Option_id")
plt.show()

plt.plot(findata["option_calculation_id"]) 
plt.title("Option_calculation_id")
plt.show()

plt.plot(findata["company_id"]) 
plt.title("Company_id")
plt.show()

plt.plot(findata["facility_type_id"]) 
plt.title("Facility_type_id")
plt.show()

plt.plot(findata["industry_type_id"]) 
plt.title("Industry_type_id")
plt.show()

plt.plot(findata["name"]) 
plt.title("Name")
plt.show()

plt.plot(findata["started_at"]) 
plt.title("Started_at")
plt.show()

plt.plot(findata["finished_at"]) 
plt.title("Finished_at")
plt.show()

plt.plot(findata["tax_rate_source"])
plt.title("Tax_rate_source")
plt.show()

plt.plot(findata["finance_discount_rate"]) 
plt.title("Finance_discount_rate")
plt.show()

plt.plot(findata["tax_exempt"]) 
plt.title("Tax_exempt")
plt.show()

plt.plot(findata["active"]) 
plt.title("Active")
plt.show()

plt.plot(findata["area_count"]) 
plt.title("Area_count")
plt.show()

plt.plot(findata["area_count_sum"])
plt.title("Area_count_sum")
plt.show()

plt.plot(findata["ave_annual_hours"])
plt.title("Ave_annual_hours")
plt.show()

plt.plot(findata["max_kwh_cost"])
plt.title("Max_kwh_cost")
plt.show()

plt.plot(findata["max_kwh_cost_simple"])
plt.title("Max_kwh_cost_simple")
plt.show()

plt.plot(findata["existing_lighting_count"])
plt.title("Existing_lighting_count")
plt.show()

plt.plot(findata["total_watts_per_product"])
plt.title("Total_watts_per_product")
plt.show()

plt.plot(findata["ave_lm70"])
plt.title("Ave_lm70")
plt.show()

plt.plot(findata["total_solution_count"])
plt.title("total_solution_count")
plt.show()

plt.plot(findata["total_existing_quantity"])
plt.title("Total_existing_quantity")
plt.show()

plt.plot(findata["total_proposed_quantity"])
plt.title("Total_proposed_quantity")
plt.show()

plt.plot(findata["total_replacement_count"])
plt.title("Total_replacement_count")
plt.show()

plt.plot(findata["total_fixture_watts"])
plt.title("Total_fixture_watts")
plt.show()

plt.plot(findata["total_fixture_watt_hours"])
plt.title("Total_fixture_watt_hours")
plt.show()

plt.plot(findata["total_fixture_life_years"])
plt.title("Total_fixture_life_years")
plt.show()

plt.plot(findata["total_item_watts"])
plt.title("Total_item_watts")
plt.show()

plt.plot(findata["sol_total_existing_count"])
plt.title("Sol_total_existing_count")
plt.show()

plt.plot(findata["total_product_count"])
plt.title("Total_product_count")
plt.show()

plt.plot(findata["energy_savings_per_year"])
plt.title("Energy_savings_per_year")
plt.show()

plt.plot(findata["total_savings_per_year"])
plt.title("Total_savings_per_year")
plt.show()

plt.plot(findata["rebates"])
plt.title("Rebates")
plt.show()

plt.plot(findata["net_replacement_cost"])
plt.title("Net_replacement_cost")
plt.show()

plt.plot(findata["payback"])
plt.title("Payback")
plt.show()

plt.plot(findata["ROI"])
plt.title("ROI")
plt.show()

plt.plot(findata["addresses_id"])
plt.title("Addresses_id")
plt.show()

plt.plot(findata["addressable_type"])
plt.title("Addressable_type")
plt.show()


plt.plot(findata["address_type"])
plt.title("Address_type")
plt.show()


plt.plot(findata["address"])
plt.title("Address")
plt.show()


plt.plot(findata["city"])
plt.title("City")
plt.show()

plt.plot(findata["zip_code"])
plt.title("Zip_code")
plt.show()


plt.plot(findata["latitude"])
plt.title("Latitude")
plt.show()


plt.plot(findata["longitude"])
plt.title("Longitude")
plt.show()

# %%
findata_1 = findata.filter(['project_id', 'option_id', 'option_calculation_id' , 'company_id', 'facility_type_id', 'industry_type_id'])
print(findata_1)
sns.pairplot(findata_1)
# Out:
#       project_id  option_id  option_calculation_id  company_id  \
# 0             11         92                   1221          15
# 1             11         92                   1221          15
# 2             11         92                   1221          15
# 3             15        928                   1781          19
# 4             15        928                   1781          19
# ...          ...        ...                    ...         ...
# 3851        3693       3590                   3555         488
# 3852        3694       3591                   3556         488
# 3853        4426       4136                   4101         488
# 3854       11734      10045                  10041         943
# 3855       12137      10284                  10280         943
#
#       facility_type_id  industry_type_id
# 0                 19.0               NaN
# 1                 19.0               NaN
# 2                 19.0               NaN
# 3                  NaN            2336.0
# 4                  NaN            2336.0
# ...                ...               ...
# 3851              65.0               NaN
# 3852              62.0               NaN
# 3853               9.0               NaN
# 3854              52.0               NaN
# 3855              62.0               NaN
#
# [3856 rows x 6 columns]

# %%
findata_2 = findata.filter(['started_at', 'finished_at','tax_rate_source', 'finance_discount_rate', 'tax_exempt', 'active'])
print(findata_2)
sns.pairplot(findata_2)
# Out:
#      started_at finished_at  tax_rate_source  finance_discount_rate  \
# 0       43:31.8     43:33.9              0.0                      5
# 1       43:31.8     43:33.9              0.0                      5
# 2       43:31.8     43:33.9              0.0                      5
# 3       55:33.8     55:40.4              NaN                      5
# 4       55:33.8     55:40.4              NaN                      5
# ...         ...         ...              ...                    ...
# 3851    28:08.7     28:11.4              2.0                      5
# 3852    38:05.2     38:07.6              2.0                      5
# 3853    53:26.7     53:31.3              2.0                      5
# 3854    35:02.2     35:04.8              2.0                      5
# 3855    40:26.2     40:28.5              2.0                      5
#
#       tax_exempt  active
# 0          False    True
# 1          False    True
# 2          False    True
# 3          False    True
# 4          False    True
# ...          ...     ...
# 3851       False    True
# 3852       False    True
# 3853       False    True
# 3854       False    True
# 3855       False    True
#
# [3856 rows x 6 columns]
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
findata_3 = findata.filter([ 'area_count', 'area_count_sum', 'ave_annual_hours', 'max_kwh_cost',
       'max_kwh_cost_simple', 'existing_lighting_count',
       'total_watts_per_product'])
print(findata_3)
sns.pairplot(findata_3)
# Out:
#       area_count  area_count_sum  ave_annual_hours  max_kwh_cost  \
# 0              1               1               NaN           NaN
# 1              1               1               NaN           NaN
# 2              1               1               NaN           NaN
# 3              6             936            3727.0          0.10
# 4              6             936            3727.0          0.10
# ...          ...             ...               ...           ...
# 3851           5              10            3200.0           NaN
# 3852           3               3            4200.0           NaN
# 3853           2             144            4800.0          0.10
# 3854           3              24            2860.0          0.12
# 3855           2               6            4368.0          0.12
#
#       max_kwh_cost_simple  existing_lighting_count  total_watts_per_product
# 0                     NaN                        1                   1080.0
# 1                     NaN                        1                   1080.0
# 2                     NaN                        1                   1080.0
# 3                     NaN                        6                 795312.0
# 4                     NaN                        6                 795312.0
# ...                   ...                      ...                      ...
# 3851                  NaN                        5                  11020.0
# 3852                  NaN                        3                   2148.0
# 3853                  NaN                        2                  70864.0
# 3854                  NaN                        3                   3222.0
# 3855                  NaN                        2                    360.0
#
# [3856 rows x 7 columns]

# %%
findata_4 = findata.filter(['ave_lm70', 'total_solution_count',
       'total_existing_quantity', 'total_proposed_quantity',
       'total_replacement_count', 'total_fixture_watts',
       'total_fixture_watt_hours'])
print(findata_4)
sns.pairplot(findata_4)

# %%
findata_5 = findata.filter(['total_fixture_life_years',
       'total_item_watts', 'sol_total_existing_count', 'total_product_count',
       'energy_savings_per_year'])
print(findata_5)
sns.pairplot(findata_5)

# %%
findata_6 = findata.filter(['total_savings_per_year', 'rebates',
       'net_replacement_cost', 'payback', 'ROI'])
print(findata_6)
sns.pairplot(findata_6)

# %%
findata_7 = findata.filter(['addresses_id',
       'addressable_type', 'address_type', 'address', 'city',
       'zip_code', 'latitude', 'longitude'])
print(findata_7)
sns.pairplot(findata_7)
